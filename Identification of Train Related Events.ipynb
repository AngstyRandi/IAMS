# %% [markdown]
# # Identification of Train Related Events

# %% [markdown]
# ## Documentation
#
# The goal of this script is to:
# 1. Identify train related events
# 2. Extract timestamps of train related events
# 3. Compute timestamp of X duration prior to the train related event to get the target periods
# 4. Remove overlaps in target time periods

# %% [markdown]
# ## Initialisation

# %% [markdown]
# ### Load libraries

# %%
# Load libraries
import pandas as pd
import numpy as np
import datetime as dt
import time

# %% [markdown]
# ### Configure display

# %%
# Enable display of all columns for dataframes with many variables
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Set Up Directory

# %%
# Check current directory location
import os
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\scripts'

# %%
# Define root file directory folder where the files are being stored
#os.chdir(cwd + alarmLoc)
os.chdir(os.path.dirname(os.getcwd()) + '\\alarm-event-logs')

# Check current directory location
cwd = os.getcwd()

# Check directory location
cwd
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\alarm-event-logs'

# %%
# Location of Alarm and Normal Event Files
srcFiles = '\\taggedOutput\\main'

# %% [markdown]
# ## Event Extraction

# %% [markdown]
# ### Load AlarmList Files

# %%
# Define root file directory folder where the files are being stored
os.chdir(cwd + srcFiles)

# Check directory location
os.getcwd()
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\alarm-event-logs\\taggedOutput\\main'

# %%
# Gather list of tagged cleaned files (ATS + CMS environments only)
dfs = [pd.read_csv(f)
        for f in os.listdir(os.getcwd()) if (f.startswith('ATS') | f.startswith('CMS'))]

# Compile list of tagged cleaned files into a single dataframe
df = pd.concat(dfs, ignore_index=True).reset_index()

# Delete redundant index col
del df["index"]

# Format time values to time format
df['DATETIME_SENT'] = pd.to_datetime(df['DATETIME_SENT'])
df['DATETIME_RECEIVED'] = pd.to_datetime(df['DATETIME_RECEIVED'])
df['EQUIPMENT_DATE'] = pd.to_datetime(df['EQUIPMENT_DATE'])
df['ACQUISITION_DATE'] = pd.to_datetime(df['ACQUISITION_DATE'])
df['SCS_TIME'] = pd.to_datetime(df['SCS_TIME'])
df['TIME_CODE'] = pd.to_datetime(df['TIME_CODE'])

# Print df summary stats
print(df.shape)
print(df.info())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (5,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# (23618450, 38)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23618450 entries, 0 to 23618449
# Data columns (total 38 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   ENTRY_CODE_SUFFIX         object
#  1   ENTRY_CODE                int64
#  2   ALARM_ID                  int64
#  3   USER_ID                   int64
#  4   EQUIPMENT_NAME            float64
#  5   VALUE                     object
#  6   VALUE_STATE               int64
#  7   ACKNOWLEDGEMENT_REQUIRED  bool
#  8   SEVERITY                  int64
#  9   HIDDEN                    bool
#  10  THEME                     int64
#  11  EQUIPMENT_DATE            datetime64[ns]
#  12  ACQUISITION_DATE          datetime64[ns]
#  13  SCS_TIME                  datetime64[ns]
#  14  FUNCTIONAL_CATEGORY       int64
#  15  GEOGRAPHICAL_CATEGORY     int64
#  16  ENVIRONMENT               object
#  17  USER1                     float64
#  18  ASSET_ID_RAW              object
#  19  ASSET_DESCRIPTION         object
#  20  EVENT_DESCRIPTION         object
#  21  EVENT_STATUS              object
#  22  OPERATOR_INITIALS         object
#  23  ASSET_DESC_CAT            object
#  24  EVENT_DESC_CAT            object
#  25  TrainID                   float64
#  26  CarID                     float64
#  27  ServiceID                 float64
#  28  AssetClass                object
#  29  AssetSubClass             object
#  30  DATETIME_SENT             datetime64[ns]
#  31  DATETIME_RECEIVED         datetime64[ns]
#  32  TIME_CODE                 datetime64[ns]
#  33  isAlarm                   bool
#  34  NuisanceAlarm             bool
#  35  RepeatAlarm               bool
#  36  AltAlarm2                 bool
#  37  AltAlarm3                 bool
# dtypes: bool(7), datetime64[ns](6), float64(5), int64(8), object(12)
# memory usage: 5.6+ GB
# None

# %%
# Inspect df
df.head()
# Out:
#   ENTRY_CODE_SUFFIX  ENTRY_CODE  ALARM_ID  USER_ID  EQUIPMENT_NAME VALUE  \
# 0                 +  -283082340        50        0             NaN     3
# 1                 +  -283082339        49        0             NaN     3
# 2                 +  -283082338        51        0             NaN     3
# 3                 +  -283084384      4654        0             NaN     1
# 4                 +  -283084241      4513        0             NaN     0
#
#    VALUE_STATE  ACKNOWLEDGEMENT_REQUIRED  SEVERITY  HIDDEN  THEME  \
# 0            0                      True         2    True      0
# 1            0                      True         2    True      0
# 2            0                      True         2    True      0
# 3            0                      True         2    True      0
# 4            0                      True         4    True      0
#
#                  EQUIPMENT_DATE              ACQUISITION_DATE  \
# 0 2020-12-30 02:09:59.609949952 2020-12-30 02:09:59.609949952
# 1 2020-12-30 02:09:59.609949952 2020-12-30 02:09:59.609949952
# 2 2020-12-30 02:09:59.609949952 2020-12-30 02:09:59.609949952
# 3 2020-12-30 02:09:59.667840000 2020-12-30 02:09:59.667840000
# 4 2020-12-30 02:09:59.667840000 2020-12-30 02:09:59.667840000
#
#                        SCS_TIME  FUNCTIONAL_CATEGORY  GEOGRAPHICAL_CATEGORY  \
# 0 2020-12-30 02:09:59.609949952                   51                     17
# 1 2020-12-30 02:09:59.609949952                   51                     17
# 2 2020-12-30 02:09:59.609949952                   51                     17
# 3 2020-12-30 02:09:59.667840000                   10                     10
# 4 2020-12-30 02:09:59.667840000                   11                     10
#
#   ENVIRONMENT  USER1         ASSET_ID_RAW          ASSET_DESCRIPTION  \
# 0      OCCATS    1.0     SCS/BGK/B1/RTU22  BGK ISCS Signalling RTU 2
# 1      OCCATS    1.0     SCS/BGK/B1/RTU21  BGK ISCS Signalling RTU 1
# 2      OCCATS    1.0    SCS/BGK/B1/PMSB02    BGK ISCS Signalling PMS
# 3      OCCATS    1.0  SIG/FRP/B2/ASCV1011                        CBI
# 4      OCCATS    1.0   SIG/FRP/B2/DCU1001            N/B PSD Door 01
#
#            EVENT_DESCRIPTION EVENT_STATUS OPERATOR_INITIALS  \
# 0    Communication with ISCS   IN SERVICE               NaN
# 1    Communication with ISCS   IN SERVICE               NaN
# 2  Communication with Server   IN SERVICE               NaN
# 3             DMS-CBI Link 2           OK               NaN
# 4             Service Status           OK               NaN
#
#                     ASSET_DESC_CAT             EVENT_DESC_CAT  TrainID  CarID  \
# 0  SUBLOCATION ISCS Signalling RTU    Communication with ISCS      NaN    NaN
# 1  SUBLOCATION ISCS Signalling RTU    Communication with ISCS      NaN    NaN
# 2  SUBLOCATION ISCS Signalling PMS  Communication with Server      NaN    NaN
# 3                              CBI               DMS-CBI Link      NaN    NaN
# 4                     N/B PSD Door             Service Status      NaN    NaN
#
#    ServiceID AssetClass AssetSubClass           DATETIME_SENT  \
# 0        NaN        SCS           RTU 2020-12-30 02:10:01.322
# 1        NaN        SCS           RTU 2020-12-30 02:10:01.322
# 2        NaN        SCS          PMSB 2020-12-30 02:10:01.322
# 3        NaN        SIG          ASCV 2020-12-30 02:10:01.322
# 4        NaN        SIG           DCU 2020-12-30 02:10:01.322
#
#         DATETIME_RECEIVED                     TIME_CODE  isAlarm  \
# 0 2020-12-30 02:10:01.322 2020-12-30 02:10:01.322298880     True
# 1 2020-12-30 02:10:01.322 2020-12-30 02:10:01.322298880     True
# 2 2020-12-30 02:10:01.322 2020-12-30 02:10:01.322298880     True
# 3 2020-12-30 02:10:01.322 2020-12-30 02:10:01.322298880    False
# 4 2020-12-30 02:10:01.322 2020-12-30 02:10:01.322298880    False
#
#    NuisanceAlarm  RepeatAlarm  AltAlarm2  AltAlarm3
# 0          False        False      False      False
# 1          False        False      False      False
# 2          False        False      False      False
# 3          False        False      False      False
# 4          False        False      False      False

# %%
# Create dictionary of target events:
targetEvents = [
                "Train Emergency Brake",
                "Brake Equipment Status",
                "Service Brake Status",
                "DT Emergency Brake From Other",
                "Emergency Brake by ATC",
                "DT All Brakes Applied Relay Status",
                "DT All Brakes Released Relay Status",
                "Service Brake Summary Status",
                "Emergency Brake Reset Request",
                "Train Stalled in Interstation",
                "Train Skip Stop Demand",
                "ATO - S_ATO_DRIV_ - Stopping point overrun",
                "ATO - S_ATO_DRIV_ - Stopping point underrun",
                "Automatic Hold applied due to TrainCar stalled in "
]

# %%
targetEvent_df = df.loc[
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[0], na=False, regex=True) | 
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[1], na=False, regex=True) |    
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[2], na=False, regex=True) |    
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[3], na=False, regex=True) |    
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[4], na=False, regex=True) |                                                           
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[5], na=False, regex=True) |    
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[6], na=False, regex=True) |    
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[7], na=False, regex=True) |    
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[8], na=False, regex=True) |                                  
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[9], na=False, regex=True) |    
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[10], na=False, regex=True) |    
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[11], na=False, regex=True) |    
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[12], na=False, regex=True) |                                                           
                        df["EVENT_DESC_CAT"].str.contains(targetEvents[13], na=False, regex=True)                                                           
                       ].reset_index()

# Delete redundant index col
del targetEvent_df["index"]

# Inspect data
targetEvent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107806 entries, 0 to 107805
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ENTRY_CODE_SUFFIX         107806 non-null  object
#  1   ENTRY_CODE                107806 non-null  int64
#  2   ALARM_ID                  107806 non-null  int64
#  3   USER_ID                   107806 non-null  int64
#  4   EQUIPMENT_NAME            0 non-null       float64
#  5   VALUE                     107806 non-null  object
#  6   VALUE_STATE               107806 non-null  int64
#  7   ACKNOWLEDGEMENT_REQUIRED  107806 non-null  bool
#  8   SEVERITY                  107806 non-null  int64
#  9   HIDDEN                    107806 non-null  bool
#  10  THEME                     107806 non-null  int64
#  11  EQUIPMENT_DATE            107806 non-null  datetime64[ns]
#  12  ACQUISITION_DATE          107806 non-null  datetime64[ns]
#  13  SCS_TIME                  107806 non-null  datetime64[ns]
#  14  FUNCTIONAL_CATEGORY       107806 non-null  int64
#  15  GEOGRAPHICAL_CATEGORY     107806 non-null  int64
#  16  ENVIRONMENT               107806 non-null  object
#  17  USER1                     97745 non-null   float64
#  18  ASSET_ID_RAW              107806 non-null  object
#  19  ASSET_DESCRIPTION         107551 non-null  object
#  20  EVENT_DESCRIPTION         107806 non-null  object
#  21  EVENT_STATUS              107502 non-null  object
#  22  OPERATOR_INITIALS         31325 non-null   object
#  23  ASSET_DESC_CAT            107551 non-null  object
#  24  EVENT_DESC_CAT            107806 non-null  object
#  25  TrainID                   2589 non-null    float64
#  26  CarID                     255 non-null     float64
#  27  ServiceID                 0 non-null       float64
#  28  AssetClass                107551 non-null  object
#  29  AssetSubClass             105097 non-null  object
#  30  DATETIME_SENT             107806 non-null  datetime64[ns]
#  31  DATETIME_RECEIVED         107806 non-null  datetime64[ns]
#  32  TIME_CODE                 107806 non-null  datetime64[ns]
#  33  isAlarm                   107806 non-null  bool
#  34  NuisanceAlarm             107806 non-null  bool
#  35  RepeatAlarm               107806 non-null  bool
#  36  AltAlarm2                 107806 non-null  bool
#  37  AltAlarm3                 107806 non-null  bool
# dtypes: bool(7), datetime64[ns](6), float64(5), int64(8), object(12)
# memory usage: 26.2+ MB

# %%
# Inspect data
targetEvent_df.head()
# Out:
#   ENTRY_CODE_SUFFIX  ENTRY_CODE  ALARM_ID  USER_ID  EQUIPMENT_NAME VALUE  \
# 0                 +  -283084238      2075        0             NaN     1
# 1                 +  -283082724      2938        0             NaN     0
# 2                 +  -283082645      2938        0             NaN     2
# 3                 +  -283084832      5097        0             NaN     1
# 4                 +  -283084833      5098        0             NaN     0
#
#    VALUE_STATE  ACKNOWLEDGEMENT_REQUIRED  SEVERITY  HIDDEN  THEME  \
# 0            1                      True         5    True      0
# 1            0                      True         3    True      0
# 2            1                      True         3    True      0
# 3            1                      True         5    True      0
# 4            0                      True         5    True      0
#
#   EQUIPMENT_DATE ACQUISITION_DATE                      SCS_TIME  \
# 0     2000-01-01       2000-01-01 2020-12-30 02:09:59.667840000
# 1     2000-01-01       2000-01-01 2020-12-30 02:09:59.667840000
# 2     2000-01-01       2000-01-01 2020-12-30 02:09:59.667840000
# 3     2000-01-01       2000-01-01 2020-12-30 02:10:01.619056896
# 4     2000-01-01       2000-01-01 2020-12-30 02:10:01.619056896
#
#    FUNCTIONAL_CATEGORY  GEOGRAPHICAL_CATEGORY ENVIRONMENT  USER1  \
# 0                   12                     27      OCCATS    1.0
# 1                   12                     27      OCCATS    1.0
# 2                   12                     27      OCCATS    1.0
# 3                   12                     27      OCCATS    1.0
# 4                   12                     27      OCCATS    1.0
#
#            ASSET_ID_RAW ASSET_DESCRIPTION              EVENT_DESCRIPTION  \
# 0             TR___0052          Cons 139  Train Stalled in Interstation
# 1  EMU/043/TRN/XXXXXXXX         Train 043  Train Stalled in Interstation
# 2  EMU/043/TRN/XXXXXXXX         Train 043  Train Stalled in Interstation
# 3             TR___0058          Cons 187          Train Emergency Brake
# 4             TR___0058          Cons 187         Emergency Brake by ATC
#
#    EVENT_STATUS OPERATOR_INITIALS ASSET_DESC_CAT  \
# 0       STALLED               NaN           Cons
# 1   NOT STALLED               NaN          Train
# 2       UNKNOWN               NaN          Train
# 3       APPLIED               NaN           Cons
# 4  INACTIVE CAB               NaN           Cons
#
#                   EVENT_DESC_CAT  TrainID  CarID  ServiceID AssetClass  \
# 0  Train Stalled in Interstation     52.0    NaN        NaN         TR
# 1  Train Stalled in Interstation      NaN    NaN        NaN        EMU
# 2  Train Stalled in Interstation      NaN    NaN        NaN        EMU
# 3          Train Emergency Brake     58.0    NaN        NaN         TR
# 4         Emergency Brake by ATC     58.0    NaN        NaN         TR
#
#   AssetSubClass           DATETIME_SENT       DATETIME_RECEIVED  \
# 0           NaN 2020-12-30 02:10:01.322 2020-12-30 02:10:01.322
# 1      XXXXXXXX 2020-12-30 02:10:01.322 2020-12-30 02:10:01.322
# 2      XXXXXXXX 2020-12-30 02:10:01.322 2020-12-30 02:10:01.322
# 3           NaN 2020-12-30 02:10:01.758 2020-12-30 02:10:01.758
# 4           NaN 2020-12-30 02:10:01.758 2020-12-30 02:10:01.758
#
#                       TIME_CODE  isAlarm  NuisanceAlarm  RepeatAlarm  \
# 0 2020-12-30 02:10:01.322298880     True          False        False
# 1 2020-12-30 02:10:01.322298880     True          False        False
# 2 2020-12-30 02:10:01.322298880    False          False        False
# 3 2020-12-30 02:10:01.758992896     True          False        False
# 4 2020-12-30 02:10:01.758992896    False          False        False
#
#    AltAlarm2  AltAlarm3
# 0      False      False
# 1      False      False
# 2      False      False
# 3      False      False
# 4      False      False

# %%
# Get Event Time
targetEvent_df.drop(targetEvent_df.columns.difference(["ENVIRONMENT","SCS_TIME"]), 1, inplace=True)

# Inspect data
targetEvent_df.head()
# Out:
#                        SCS_TIME ENVIRONMENT
# 0 2020-12-30 02:09:59.667840000      OCCATS
# 1 2020-12-30 02:09:59.667840000      OCCATS
# 2 2020-12-30 02:09:59.667840000      OCCATS
# 3 2020-12-30 02:10:01.619056896      OCCATS
# 4 2020-12-30 02:10:01.619056896      OCCATS

# %%
# Get Target Time Periods
offsetTime_minus = -10 # time in seconds
offsetTime_plus = 0 # time in seconds
targetEvent_df["SCS_TIME_minusT"] = targetEvent_df["SCS_TIME"] + pd.Timedelta(seconds = offsetTime_minus)
targetEvent_df["SCS_TIME_plusT"] = targetEvent_df["SCS_TIME"] + pd.Timedelta(seconds = offsetTime_plus)

# Inspect data
targetEvent_df.head()
# Out:
#                        SCS_TIME ENVIRONMENT               SCS_TIME_minusT  \
# 0 2020-12-30 02:09:59.667840000      OCCATS 2020-12-30 02:09:49.667840000
# 1 2020-12-30 02:09:59.667840000      OCCATS 2020-12-30 02:09:49.667840000
# 2 2020-12-30 02:09:59.667840000      OCCATS 2020-12-30 02:09:49.667840000
# 3 2020-12-30 02:10:01.619056896      OCCATS 2020-12-30 02:09:51.619056896
# 4 2020-12-30 02:10:01.619056896      OCCATS 2020-12-30 02:09:51.619056896
#
#                  SCS_TIME_plusT
# 0 2020-12-30 02:09:59.667840000
# 1 2020-12-30 02:09:59.667840000
# 2 2020-12-30 02:09:59.667840000
# 3 2020-12-30 02:10:01.619056896
# 4 2020-12-30 02:10:01.619056896

# %%
# Inspect data
targetEvent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107806 entries, 0 to 107805
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SCS_TIME         107806 non-null  datetime64[ns]
#  1   ENVIRONMENT      107806 non-null  object
#  2   SCS_TIME_minusT  107806 non-null  datetime64[ns]
#  3   SCS_TIME_plusT   107806 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), object(1)
# memory usage: 3.3+ MB

# %% [markdown]
# ### Simplify Time Ranges

# %%
# Get Drop Redundant Columns
targetEvent_df.drop(targetEvent_df.columns.difference(["SCS_TIME_minusT", "SCS_TIME_plusT"]), 1, inplace=True)

# Remove duplicates
targetEvent_df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=True)

# Sort data by time for ease of export in chronological order
df = df.sort_values(["SCS_TIME"], ignore_index=True) 

# Inspect data
targetEvent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107806 entries, 0 to 107805
# Data columns (total 2 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SCS_TIME_minusT  107806 non-null  datetime64[ns]
#  1   SCS_TIME_plusT   107806 non-null  datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 1.6 MB

# %%
# Inspect data
targetEvent_df.head()
# Out:
#                 SCS_TIME_minusT                SCS_TIME_plusT
# 0 2020-12-30 02:09:49.667840000 2020-12-30 02:09:59.667840000
# 1 2020-12-30 02:09:49.667840000 2020-12-30 02:09:59.667840000
# 2 2020-12-30 02:09:49.667840000 2020-12-30 02:09:59.667840000
# 3 2020-12-30 02:09:51.619056896 2020-12-30 02:10:01.619056896
# 4 2020-12-30 02:09:51.619056896 2020-12-30 02:10:01.619056896

# %%
# Convert data to list array
temp_list = targetEvent_df.values.tolist()
temp_list[0:5]
# Out:
# [[1609294189667840000, 1609294199667840000],
#  [1609294189667840000, 1609294199667840000],
#  [1609294189667840000, 1609294199667840000],
#  [1609294191619056896, 1609294201619056896],
#  [1609294191619056896, 1609294201619056896]]

# %%
# Consolidate overlapping timings 10 folds
for counter in range(10):
    temp_list.sort(key=lambda interval: interval[0])
    merged = [temp_list[0]]
    for current in temp_list:
        previous = merged[-1]
        if current[0] <= previous[1]:
            previous[1] = max(previous[1], current[1])
        else:
            merged.append(current)
   

print(len(merged))
merged[0:5]
# Out:
# 30600
# [[1609294189667840000, 1609294201896118016],
#  [1609294206206928896, 1609294216206928896],
#  [1609296875768499968, 1609296888613876992],
#  [1609296893748866048, 1609296913849339904],
#  [1609296925343454976, 1609296951247840000]]

# %%
targetEvent_df = pd.DataFrame.from_records(merged, columns = ["SCS_TIME_minusT", "SCS_TIME_plusT"])

# Remove duplicates
targetEvent_df = targetEvent_df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=True)

# Inspect data
targetEvent_df.head()
# Out:
#        SCS_TIME_minusT       SCS_TIME_plusT
# 0  1609294189667840000  1609294201896118016
# 1  1609294206206928896  1609294216206928896
# 2  1609296875768499968  1609296888613876992
# 3  1609296893748866048  1609296913849339904
# 4  1609296925343454976  1609296951247840000

# %%
targetEvent_df['SCS_TIME_minusT']=pd.to_datetime(targetEvent_df['SCS_TIME_minusT'])
targetEvent_df['SCS_TIME_plusT']=pd.to_datetime(targetEvent_df['SCS_TIME_plusT'])

# Inspect data
targetEvent_df.head()
# Out:
#                 SCS_TIME_minusT                SCS_TIME_plusT
# 0 2020-12-30 02:09:49.667840000 2020-12-30 02:10:01.896118016
# 1 2020-12-30 02:10:06.206928896 2020-12-30 02:10:16.206928896
# 2 2020-12-30 02:54:35.768499968 2020-12-30 02:54:48.613876992
# 3 2020-12-30 02:54:53.748866048 2020-12-30 02:55:13.849339904
# 4 2020-12-30 02:55:25.343454976 2020-12-30 02:55:51.247840000

# %%
# Inspect data
targetEvent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30600 entries, 0 to 30599
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SCS_TIME_minusT  30600 non-null  datetime64[ns]
#  1   SCS_TIME_plusT   30600 non-null  datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 478.2 KB

# %% [markdown]
# ## Filter Time

# %%
# Initialise
eventSplice0 = df.loc[(df["SCS_TIME"] >= targetEvent_df['SCS_TIME_minusT'][0]) & 
                      (df["SCS_TIME"] <= targetEvent_df['SCS_TIME_plusT'][0])
                     ].reset_index()
# Delete redundant index col
del eventSplice0["index"]


maxCounter = len(targetEvent_df)
counter = 1

# Inspect data
eventSplice0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2568 entries, 0 to 2567
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENTRY_CODE_SUFFIX         2568 non-null   object
#  1   ENTRY_CODE                2568 non-null   int64
#  2   ALARM_ID                  2568 non-null   int64
#  3   USER_ID                   2568 non-null   int64
#  4   EQUIPMENT_NAME            0 non-null      float64
#  5   VALUE                     2568 non-null   object
#  6   VALUE_STATE               2568 non-null   int64
#  7   ACKNOWLEDGEMENT_REQUIRED  2568 non-null   bool
#  8   SEVERITY                  2568 non-null   int64
#  9   HIDDEN                    2568 non-null   bool
#  10  THEME                     2568 non-null   int64
#  11  EQUIPMENT_DATE            2568 non-null   datetime64[ns]
#  12  ACQUISITION_DATE          2568 non-null   datetime64[ns]
#  13  SCS_TIME                  2568 non-null   datetime64[ns]
#  14  FUNCTIONAL_CATEGORY       2568 non-null   int64
#  15  GEOGRAPHICAL_CATEGORY     2568 non-null   int64
#  16  ENVIRONMENT               2568 non-null   object
#  17  USER1                     2567 non-null   float64
#  18  ASSET_ID_RAW              2568 non-null   object
#  19  ASSET_DESCRIPTION         2568 non-null   object
#  20  EVENT_DESCRIPTION         2568 non-null   object
#  21  EVENT_STATUS              2568 non-null   object
#  22  OPERATOR_INITIALS         1 non-null      object
#  23  ASSET_DESC_CAT            2568 non-null   object
#  24  EVENT_DESC_CAT            2568 non-null   object
#  25  TrainID                   15 non-null     float64
#  26  CarID                     0 non-null      float64
#  27  ServiceID                 0 non-null      float64
#  28  AssetClass                2532 non-null   object
#  29  AssetSubClass             2437 non-null   object
#  30  DATETIME_SENT             2568 non-null   datetime64[ns]
#  31  DATETIME_RECEIVED         2568 non-null   datetime64[ns]
#  32  TIME_CODE                 2568 non-null   datetime64[ns]
#  33  isAlarm                   2568 non-null   bool
#  34  NuisanceAlarm             2568 non-null   bool
#  35  RepeatAlarm               2568 non-null   bool
#  36  AltAlarm2                 2568 non-null   bool
#  37  AltAlarm3                 2568 non-null   bool
# dtypes: bool(7), datetime64[ns](6), float64(5), int64(8), object(12)
# memory usage: 639.6+ KB

# %%
# Inspect data
eventSplice0.head()
# Out:
#   ENTRY_CODE_SUFFIX  ENTRY_CODE  ALARM_ID  USER_ID  EQUIPMENT_NAME VALUE  \
# 0                 + -1172283365   2574946        0             NaN     0
# 1                 + -1172283366   2574947        0             NaN     0
# 2                 + -1172283370   2573986        0             NaN     0
# 3                 + -1172283369   2573986        0             NaN     1
# 4                 + -1172283368   2574949        0             NaN     1
#
#    VALUE_STATE  ACKNOWLEDGEMENT_REQUIRED  SEVERITY  HIDDEN  THEME  \
# 0            0                      True         3    True      0
# 1            0                      True         3    True      0
# 2            1                      True         2    True      0
# 3            0                      True         2    True      0
# 4            0                      True         3    True      0
#
#                  EQUIPMENT_DATE              ACQUISITION_DATE  \
# 0 2020-12-30 02:09:50.324232192 2020-12-30 02:09:50.324232192
# 1 2020-12-30 02:09:50.577306880 2020-12-30 02:09:50.577306880
# 2 2020-12-30 02:09:51.588258048 2020-12-30 02:09:51.588258048
# 3 2020-12-30 02:09:51.588258048 2020-12-30 02:09:51.588258048
# 4 2020-12-30 02:09:51.832740096 2020-12-30 02:09:51.832740096
#
#                        SCS_TIME  FUNCTIONAL_CATEGORY  GEOGRAPHICAL_CATEGORY  \
# 0 2020-12-30 02:09:50.324232192                   40                      5
# 1 2020-12-30 02:09:50.577306880                   40                     11
# 2 2020-12-30 02:09:51.588258048                   51                     17
# 3 2020-12-30 02:09:51.588258048                   51                     17
# 4 2020-12-30 02:09:51.832740096                   40                      9
#
#   ENVIRONMENT  USER1      ASSET_ID_RAW ASSET_DESCRIPTION EVENT_DESCRIPTION  \
# 0      OCCCMS    1.0  COM/OTP/B3/CAM60     OTP:222 AFG 8            Status
# 1      OCCCMS    1.0  COM/BNK/B1/CAM22  BNK:210 SUBWY3E3            Status
# 2      OCCCMS    1.0  SCS/BGK/B1/PLC01    BGK ISCS PLC 1  Mux Selection 01
# 3      OCCCMS    1.0  SCS/BGK/B1/PLC01    BGK ISCS PLC 1  Mux Selection 01
# 4      OCCCMS    1.0  COM/LTI/B2/CAM11   LTI:111 PHONE 1            Status
#
#   EVENT_STATUS OPERATOR_INITIALS        ASSET_DESC_CAT EVENT_DESC_CAT  \
# 0       NORMAL               NaN                   AFG         Status
# 1       NORMAL               NaN                SUBWYE         Status
# 2        FAULT               NaN  SUBLOCATION ISCS PLC  Mux Selection
# 3       NORMAL               NaN  SUBLOCATION ISCS PLC  Mux Selection
# 4      FAILURE               NaN                 PHONE         Status
#
#    TrainID  CarID  ServiceID AssetClass AssetSubClass           DATETIME_SENT  \
# 0      NaN    NaN        NaN        COM           CAM 2020-12-30 02:09:50.503
# 1      NaN    NaN        NaN        COM           CAM 2020-12-30 02:09:51.504
# 2      NaN    NaN        NaN        SCS           PLC 2020-12-30 02:09:52.503
# 3      NaN    NaN        NaN        SCS           PLC 2020-12-30 02:09:52.503
# 4      NaN    NaN        NaN        COM           CAM 2020-12-30 02:09:51.504
#
#         DATETIME_RECEIVED                     TIME_CODE  isAlarm  \
# 0 2020-12-30 02:09:50.503 2020-12-30 02:09:50.503602944    False
# 1 2020-12-30 02:09:51.504 2020-12-30 02:09:51.504785920    False
# 2 2020-12-30 02:09:52.503 2020-12-30 02:09:52.503451136     True
# 3 2020-12-30 02:09:52.503 2020-12-30 02:09:52.503451136    False
# 4 2020-12-30 02:09:51.504 2020-12-30 02:09:51.504785920    False
#
#    NuisanceAlarm  RepeatAlarm  AltAlarm2  AltAlarm3
# 0           True        False       True       True
# 1           True        False       True       True
# 2          False        False      False      False
# 3           True         True      False      False
# 4           True        False       True       True

# %%
while (counter < maxCounter):
    eventSplice = df.loc[(df["SCS_TIME"] >= targetEvent_df['SCS_TIME_minusT'][counter]) & 
                         (df["SCS_TIME"] <= targetEvent_df['SCS_TIME_plusT'][counter])
                        ].reset_index()
    # Delete redundant index col
    del eventSplice["index"]
    
    # Merge processed data
    eventSplice0 = pd.concat([eventSplice0, eventSplice])
    
    # Update Counter
    counter = counter + 1

# Inspect data
eventSplice0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3719829 entries, 0 to 8
# Data columns (total 38 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   ENTRY_CODE_SUFFIX         object
#  1   ENTRY_CODE                int64
#  2   ALARM_ID                  int64
#  3   USER_ID                   int64
#  4   EQUIPMENT_NAME            float64
#  5   VALUE                     object
#  6   VALUE_STATE               int64
#  7   ACKNOWLEDGEMENT_REQUIRED  bool
#  8   SEVERITY                  int64
#  9   HIDDEN                    bool
#  10  THEME                     int64
#  11  EQUIPMENT_DATE            datetime64[ns]
#  12  ACQUISITION_DATE          datetime64[ns]
#  13  SCS_TIME                  datetime64[ns]
#  14  FUNCTIONAL_CATEGORY       int64
#  15  GEOGRAPHICAL_CATEGORY     int64
#  16  ENVIRONMENT               object
#  17  USER1                     float64
#  18  ASSET_ID_RAW              object
#  19  ASSET_DESCRIPTION         object
#  20  EVENT_DESCRIPTION         object
#  21  EVENT_STATUS              object
#  22  OPERATOR_INITIALS         object
#  23  ASSET_DESC_CAT            object
#  24  EVENT_DESC_CAT            object
#  25  TrainID                   float64
#  26  CarID                     float64
#  27  ServiceID                 float64
#  28  AssetClass                object
#  29  AssetSubClass             object
#  30  DATETIME_SENT             datetime64[ns]
#  31  DATETIME_RECEIVED         datetime64[ns]
#  32  TIME_CODE                 datetime64[ns]
#  33  isAlarm                   bool
#  34  NuisanceAlarm             bool
#  35  RepeatAlarm               bool
#  36  AltAlarm2                 bool
#  37  AltAlarm3                 bool
# dtypes: bool(7), datetime64[ns](6), float64(5), int64(8), object(12)
# memory usage: 933.0+ MB

# %% [markdown]
# ### Sort Data by Time

# %%
eventSplice0.head()
# Out:
#   ENTRY_CODE_SUFFIX  ENTRY_CODE  ALARM_ID  USER_ID  EQUIPMENT_NAME VALUE  \
# 0                 + -1172283365   2574946        0             NaN     0
# 1                 + -1172283366   2574947        0             NaN     0
# 2                 + -1172283370   2573986        0             NaN     0
# 3                 + -1172283369   2573986        0             NaN     1
# 4                 + -1172283368   2574949        0             NaN     1
#
#    VALUE_STATE  ACKNOWLEDGEMENT_REQUIRED  SEVERITY  HIDDEN  THEME  \
# 0            0                      True         3    True      0
# 1            0                      True         3    True      0
# 2            1                      True         2    True      0
# 3            0                      True         2    True      0
# 4            0                      True         3    True      0
#
#                  EQUIPMENT_DATE              ACQUISITION_DATE  \
# 0 2020-12-30 02:09:50.324232192 2020-12-30 02:09:50.324232192
# 1 2020-12-30 02:09:50.577306880 2020-12-30 02:09:50.577306880
# 2 2020-12-30 02:09:51.588258048 2020-12-30 02:09:51.588258048
# 3 2020-12-30 02:09:51.588258048 2020-12-30 02:09:51.588258048
# 4 2020-12-30 02:09:51.832740096 2020-12-30 02:09:51.832740096
#
#                        SCS_TIME  FUNCTIONAL_CATEGORY  GEOGRAPHICAL_CATEGORY  \
# 0 2020-12-30 02:09:50.324232192                   40                      5
# 1 2020-12-30 02:09:50.577306880                   40                     11
# 2 2020-12-30 02:09:51.588258048                   51                     17
# 3 2020-12-30 02:09:51.588258048                   51                     17
# 4 2020-12-30 02:09:51.832740096                   40                      9
#
#   ENVIRONMENT  USER1      ASSET_ID_RAW ASSET_DESCRIPTION EVENT_DESCRIPTION  \
# 0      OCCCMS    1.0  COM/OTP/B3/CAM60     OTP:222 AFG 8            Status
# 1      OCCCMS    1.0  COM/BNK/B1/CAM22  BNK:210 SUBWY3E3            Status
# 2      OCCCMS    1.0  SCS/BGK/B1/PLC01    BGK ISCS PLC 1  Mux Selection 01
# 3      OCCCMS    1.0  SCS/BGK/B1/PLC01    BGK ISCS PLC 1  Mux Selection 01
# 4      OCCCMS    1.0  COM/LTI/B2/CAM11   LTI:111 PHONE 1            Status
#
#   EVENT_STATUS OPERATOR_INITIALS        ASSET_DESC_CAT EVENT_DESC_CAT  \
# 0       NORMAL               NaN                   AFG         Status
# 1       NORMAL               NaN                SUBWYE         Status
# 2        FAULT               NaN  SUBLOCATION ISCS PLC  Mux Selection
# 3       NORMAL               NaN  SUBLOCATION ISCS PLC  Mux Selection
# 4      FAILURE               NaN                 PHONE         Status
#
#    TrainID  CarID  ServiceID AssetClass AssetSubClass           DATETIME_SENT  \
# 0      NaN    NaN        NaN        COM           CAM 2020-12-30 02:09:50.503
# 1      NaN    NaN        NaN        COM           CAM 2020-12-30 02:09:51.504
# 2      NaN    NaN        NaN        SCS           PLC 2020-12-30 02:09:52.503
# 3      NaN    NaN        NaN        SCS           PLC 2020-12-30 02:09:52.503
# 4      NaN    NaN        NaN        COM           CAM 2020-12-30 02:09:51.504
#
#         DATETIME_RECEIVED                     TIME_CODE  isAlarm  \
# 0 2020-12-30 02:09:50.503 2020-12-30 02:09:50.503602944    False
# 1 2020-12-30 02:09:51.504 2020-12-30 02:09:51.504785920    False
# 2 2020-12-30 02:09:52.503 2020-12-30 02:09:52.503451136     True
# 3 2020-12-30 02:09:52.503 2020-12-30 02:09:52.503451136    False
# 4 2020-12-30 02:09:51.504 2020-12-30 02:09:51.504785920    False
#
#    NuisanceAlarm  RepeatAlarm  AltAlarm2  AltAlarm3
# 0           True        False       True       True
# 1           True        False       True       True
# 2          False        False      False      False
# 3           True         True      False      False
# 4           True        False       True       True

# %%
eventSplice0.tail()
# Out:
#   ENTRY_CODE_SUFFIX  ENTRY_CODE  ALARM_ID  USER_ID  EQUIPMENT_NAME VALUE  \
# 4                 +  -287126212   1444975        0             NaN     1
# 5                 +  -287126214   1457046        0             NaN     0
# 6                 +  -287126215   1457047        0             NaN     0
# 7                 +  -287126209   1457014        0             NaN     0
# 8                 +  -287126213   1457045        0             NaN     0
#
#    VALUE_STATE  ACKNOWLEDGEMENT_REQUIRED  SEVERITY  HIDDEN  THEME  \
# 4            1                      True         5    True      0
# 5            1                      True         7    True      0
# 6            1                      True         7    True      0
# 7            1                      True         5    True      0
# 8            0                      True         3    True      0
#
#                  EQUIPMENT_DATE              ACQUISITION_DATE  \
# 4 2000-01-01 00:00:00.000000000 2000-01-01 00:00:00.000000000
# 5 2021-02-01 01:46:35.729468160 2021-02-01 01:46:35.729468160
# 6 2021-02-01 01:46:36.737451008 2021-02-01 01:46:36.737451008
# 7 2000-01-01 00:00:00.000000000 2000-01-01 00:00:00.000000000
# 8 2000-01-01 00:00:00.000000000 2000-01-01 00:00:00.000000000
#
#                        SCS_TIME  FUNCTIONAL_CATEGORY  GEOGRAPHICAL_CATEGORY  \
# 4 2021-02-01 01:46:38.912076032                   12                     27
# 5 2021-02-01 01:46:38.912076032                   11                      3
# 6 2021-02-01 01:46:38.912076032                   11                      3
# 7 2021-02-01 01:46:38.912076032                   12                     27
# 8 2021-02-01 01:46:38.912076032                   12                     27
#
#   ENVIRONMENT  USER1           ASSET_ID_RAW ASSET_DESCRIPTION  \
# 4      OCCATS    1.0              TR___0052          Cons 139
# 5      OCCATS    1.0  SIG/NED/1211/SPKS0001   NED NB SPKS (1)
# 6      OCCATS    1.0  SIG/NED/1211/SPKS0003   NED SB SPKS (3)
# 7      OCCATS    1.0              TR___0052          Cons 139
# 8      OCCATS    1.0              TR___0052          Cons 139
#
#              EVENT_DESCRIPTION  EVENT_STATUS OPERATOR_INITIALS  \
# 4  Active Cab Auto-Test Status       FAILURE               ARA
# 5                       Status      OPERATED               ARA
# 6                       Status      OPERATED               ARA
# 7  State of Train Localisation  DE-LOCALISED               ARA
# 8        Train Emergency Brake   NOT APPLIED               ARA
#
#            ASSET_DESC_CAT               EVENT_DESC_CAT  TrainID  CarID  \
# 4                    Cons  Active Cab Auto-Test Status     52.0    NaN
# 5  SUBLOCATION NB SPKS ()                       Status      NaN    NaN
# 6  SUBLOCATION SB SPKS ()                       Status      NaN    NaN
# 7                    Cons  State of Train Localisation     52.0    NaN
# 8                    Cons        Train Emergency Brake     52.0    NaN
#
#    ServiceID AssetClass AssetSubClass           DATETIME_SENT  \
# 4        NaN         TR           NaN 2021-02-01 01:46:39.003
# 5        NaN        SIG          SPKS 2021-02-01 01:46:39.003
# 6        NaN        SIG          SPKS 2021-02-01 01:46:39.003
# 7        NaN         TR           NaN 2021-02-01 01:46:39.003
# 8        NaN         TR           NaN 2021-02-01 01:46:39.003
#
#         DATETIME_RECEIVED                  TIME_CODE  isAlarm  NuisanceAlarm  \
# 4 2021-02-01 01:46:39.003 2021-02-01 01:46:39.336800     True          False
# 5 2021-02-01 01:46:39.003 2021-02-01 01:46:39.336800     True           True
# 6 2021-02-01 01:46:39.003 2021-02-01 01:46:39.336800     True           True
# 7 2021-02-01 01:46:39.003 2021-02-01 01:46:39.336800     True          False
# 8 2021-02-01 01:46:39.003 2021-02-01 01:46:39.336800    False           True
#
#    RepeatAlarm  AltAlarm2  AltAlarm3
# 4        False      False      False
# 5         True      False      False
# 6         True      False      False
# 7        False      False      False
# 8         True      False      False

# %%
# Sort data by time for ease of export in chronological order (TEST)
#df.sort_values(["SCS_TIME"], ignore_index=True)

# %%
# Sort data by time for ease of export in chronological order
eventSplice0 = eventSplice0.sort_values(["SCS_TIME"], ignore_index=True)

# %%
eventSplice0.head()
# Out:
#   ENTRY_CODE_SUFFIX  ENTRY_CODE  ALARM_ID  USER_ID  EQUIPMENT_NAME VALUE  \
# 0                 + -1172283365   2574946        0             NaN     0
# 1                 + -1172283366   2574947        0             NaN     0
# 2                 + -1172283370   2573986        0             NaN     0
# 3                 + -1172283369   2573986        0             NaN     1
# 4                 + -1172283368   2574949        0             NaN     1
#
#    VALUE_STATE  ACKNOWLEDGEMENT_REQUIRED  SEVERITY  HIDDEN  THEME  \
# 0            0                      True         3    True      0
# 1            0                      True         3    True      0
# 2            1                      True         2    True      0
# 3            0                      True         2    True      0
# 4            0                      True         3    True      0
#
#                  EQUIPMENT_DATE              ACQUISITION_DATE  \
# 0 2020-12-30 02:09:50.324232192 2020-12-30 02:09:50.324232192
# 1 2020-12-30 02:09:50.577306880 2020-12-30 02:09:50.577306880
# 2 2020-12-30 02:09:51.588258048 2020-12-30 02:09:51.588258048
# 3 2020-12-30 02:09:51.588258048 2020-12-30 02:09:51.588258048
# 4 2020-12-30 02:09:51.832740096 2020-12-30 02:09:51.832740096
#
#                        SCS_TIME  FUNCTIONAL_CATEGORY  GEOGRAPHICAL_CATEGORY  \
# 0 2020-12-30 02:09:50.324232192                   40                      5
# 1 2020-12-30 02:09:50.577306880                   40                     11
# 2 2020-12-30 02:09:51.588258048                   51                     17
# 3 2020-12-30 02:09:51.588258048                   51                     17
# 4 2020-12-30 02:09:51.832740096                   40                      9
#
#   ENVIRONMENT  USER1      ASSET_ID_RAW ASSET_DESCRIPTION EVENT_DESCRIPTION  \
# 0      OCCCMS    1.0  COM/OTP/B3/CAM60     OTP:222 AFG 8            Status
# 1      OCCCMS    1.0  COM/BNK/B1/CAM22  BNK:210 SUBWY3E3            Status
# 2      OCCCMS    1.0  SCS/BGK/B1/PLC01    BGK ISCS PLC 1  Mux Selection 01
# 3      OCCCMS    1.0  SCS/BGK/B1/PLC01    BGK ISCS PLC 1  Mux Selection 01
# 4      OCCCMS    1.0  COM/LTI/B2/CAM11   LTI:111 PHONE 1            Status
#
#   EVENT_STATUS OPERATOR_INITIALS        ASSET_DESC_CAT EVENT_DESC_CAT  \
# 0       NORMAL               NaN                   AFG         Status
# 1       NORMAL               NaN                SUBWYE         Status
# 2        FAULT               NaN  SUBLOCATION ISCS PLC  Mux Selection
# 3       NORMAL               NaN  SUBLOCATION ISCS PLC  Mux Selection
# 4      FAILURE               NaN                 PHONE         Status
#
#    TrainID  CarID  ServiceID AssetClass AssetSubClass           DATETIME_SENT  \
# 0      NaN    NaN        NaN        COM           CAM 2020-12-30 02:09:50.503
# 1      NaN    NaN        NaN        COM           CAM 2020-12-30 02:09:51.504
# 2      NaN    NaN        NaN        SCS           PLC 2020-12-30 02:09:52.503
# 3      NaN    NaN        NaN        SCS           PLC 2020-12-30 02:09:52.503
# 4      NaN    NaN        NaN        COM           CAM 2020-12-30 02:09:51.504
#
#         DATETIME_RECEIVED                     TIME_CODE  isAlarm  \
# 0 2020-12-30 02:09:50.503 2020-12-30 02:09:50.503602944    False
# 1 2020-12-30 02:09:51.504 2020-12-30 02:09:51.504785920    False
# 2 2020-12-30 02:09:52.503 2020-12-30 02:09:52.503451136     True
# 3 2020-12-30 02:09:52.503 2020-12-30 02:09:52.503451136    False
# 4 2020-12-30 02:09:51.504 2020-12-30 02:09:51.504785920    False
#
#    NuisanceAlarm  RepeatAlarm  AltAlarm2  AltAlarm3
# 0           True        False       True       True
# 1           True        False       True       True
# 2          False        False      False      False
# 3           True         True      False      False
# 4           True        False       True       True

# %%
eventSplice0.tail()
# Out:
#         ENTRY_CODE_SUFFIX  ENTRY_CODE  ALARM_ID  USER_ID  EQUIPMENT_NAME  \
# 3719824                 +  -287126209   1457014        0             NaN
# 3719825                 +  -287126211   1457015        0             NaN
# 3719826                 +  -287126210   1444971        0             NaN
# 3719827                 +  -287126212   1444975        0             NaN
# 3719828                 +  -287126213   1457045        0             NaN
#
#         VALUE  VALUE_STATE  ACKNOWLEDGEMENT_REQUIRED  SEVERITY  HIDDEN  THEME  \
# 3719824     0            1                      True         5    True      0
# 3719825     3            1                      True         5    True      0
# 3719826     1            1                      True         5    True      0
# 3719827     1            1                      True         5    True      0
# 3719828     0            0                      True         3    True      0
#
#         EQUIPMENT_DATE ACQUISITION_DATE                      SCS_TIME  \
# 3719824     2000-01-01       2000-01-01 2021-02-01 01:46:38.912076032
# 3719825     2000-01-01       2000-01-01 2021-02-01 01:46:38.912076032
# 3719826     2000-01-01       2000-01-01 2021-02-01 01:46:38.912076032
# 3719827     2000-01-01       2000-01-01 2021-02-01 01:46:38.912076032
# 3719828     2000-01-01       2000-01-01 2021-02-01 01:46:38.912076032
#
#          FUNCTIONAL_CATEGORY  GEOGRAPHICAL_CATEGORY ENVIRONMENT  USER1  \
# 3719824                   12                     27      OCCATS    1.0
# 3719825                   12                     27      OCCATS    1.0
# 3719826                   12                     27      OCCATS    1.0
# 3719827                   12                     27      OCCATS    1.0
# 3719828                   12                     27      OCCATS    1.0
#
#         ASSET_ID_RAW ASSET_DESCRIPTION            EVENT_DESCRIPTION  \
# 3719824    TR___0052          Cons 139  State of Train Localisation
# 3719825    TR___0052          Cons 139    Train Driving Mode Status
# 3719826    TR___0052          Cons 139                 Availability
# 3719827    TR___0052          Cons 139  Active Cab Auto-Test Status
# 3719828    TR___0052          Cons 139        Train Emergency Brake
#
#           EVENT_STATUS OPERATOR_INITIALS ASSET_DESC_CAT  \
# 3719824   DE-LOCALISED               ARA           Cons
# 3719825     RM FORWARD               ARA           Cons
# 3719826  NOT AVAILABLE               ARA           Cons
# 3719827        FAILURE               ARA           Cons
# 3719828    NOT APPLIED               ARA           Cons
#
#                       EVENT_DESC_CAT  TrainID  CarID  ServiceID AssetClass  \
# 3719824  State of Train Localisation     52.0    NaN        NaN         TR
# 3719825    Train Driving Mode Status     52.0    NaN        NaN         TR
# 3719826                 Availability     52.0    NaN        NaN         TR
# 3719827  Active Cab Auto-Test Status     52.0    NaN        NaN         TR
# 3719828        Train Emergency Brake     52.0    NaN        NaN         TR
#
#         AssetSubClass           DATETIME_SENT       DATETIME_RECEIVED  \
# 3719824           NaN 2021-02-01 01:46:39.003 2021-02-01 01:46:39.003
# 3719825           NaN 2021-02-01 01:46:39.003 2021-02-01 01:46:39.003
# 3719826           NaN 2021-02-01 01:46:39.003 2021-02-01 01:46:39.003
# 3719827           NaN 2021-02-01 01:46:39.003 2021-02-01 01:46:39.003
# 3719828           NaN 2021-02-01 01:46:39.003 2021-02-01 01:46:39.003
#
#                          TIME_CODE  isAlarm  NuisanceAlarm  RepeatAlarm  \
# 3719824 2021-02-01 01:46:39.336800     True          False        False
# 3719825 2021-02-01 01:46:39.336800     True          False        False
# 3719826 2021-02-01 01:46:39.336800     True          False        False
# 3719827 2021-02-01 01:46:39.336800     True          False        False
# 3719828 2021-02-01 01:46:39.336800    False           True         True
#
#          AltAlarm2  AltAlarm3
# 3719824      False      False
# 3719825      False      False
# 3719826      False      False
# 3719827      False      False
# 3719828      False      False

# %%
eventSplice0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3719829 entries, 0 to 3719828
# Data columns (total 38 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   ENTRY_CODE_SUFFIX         object
#  1   ENTRY_CODE                int64
#  2   ALARM_ID                  int64
#  3   USER_ID                   int64
#  4   EQUIPMENT_NAME            float64
#  5   VALUE                     object
#  6   VALUE_STATE               int64
#  7   ACKNOWLEDGEMENT_REQUIRED  bool
#  8   SEVERITY                  int64
#  9   HIDDEN                    bool
#  10  THEME                     int64
#  11  EQUIPMENT_DATE            datetime64[ns]
#  12  ACQUISITION_DATE          datetime64[ns]
#  13  SCS_TIME                  datetime64[ns]
#  14  FUNCTIONAL_CATEGORY       int64
#  15  GEOGRAPHICAL_CATEGORY     int64
#  16  ENVIRONMENT               object
#  17  USER1                     float64
#  18  ASSET_ID_RAW              object
#  19  ASSET_DESCRIPTION         object
#  20  EVENT_DESCRIPTION         object
#  21  EVENT_STATUS              object
#  22  OPERATOR_INITIALS         object
#  23  ASSET_DESC_CAT            object
#  24  EVENT_DESC_CAT            object
#  25  TrainID                   float64
#  26  CarID                     float64
#  27  ServiceID                 float64
#  28  AssetClass                object
#  29  AssetSubClass             object
#  30  DATETIME_SENT             datetime64[ns]
#  31  DATETIME_RECEIVED         datetime64[ns]
#  32  TIME_CODE                 datetime64[ns]
#  33  isAlarm                   bool
#  34  NuisanceAlarm             bool
#  35  RepeatAlarm               bool
#  36  AltAlarm2                 bool
#  37  AltAlarm3                 bool
# dtypes: bool(7), datetime64[ns](6), float64(5), int64(8), object(12)
# memory usage: 904.6+ MB

# %% [markdown]
# ## Export File

# %%
# Check current directory
cwd
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\alarm-event-logs'

# %%
# Define Save Location
saveLoc = '\\testOutput\\'
#os.chdir(cwd + alarmLoc)
os.chdir(cwd + saveLoc)
# Check directory location
print(os.getcwd())
# Out:
# C:\Users\cftfda01\Documents\SBST Train IAMS Project\alarm-event-logs\testOutput

# %%
# Define File Save Parameters
FileName = "Potential Train Events Raw"
Run = "-B0001"
# True for single file output; # False for multiple file output; "both" for both Single & Multiple File Output
singleSave = "both"

# Get length of dataframe
df_len = len(eventSplice0)
# Inspect data
print(df_len)

# Define Size of Partitioned Dataframes
partionSize = 500000

# Define Number of Partitions (Always Round Up to Nearest Interger)
if (df_len == partionSize): 
    partitions = 1
else:
    partitions = df_len // partionSize + 1

# Inspect data
print(partitions)
# Out:
# 3719829
# 8

# %%
# Export file based on above settings
if singleSave == True:
    fileNameN = FileName + Run + '-alarmsTagged' + '.csv'
    eventSplice0.to_csv("main/" + fileNameN, index=False)
    print(fileNameN + " SAVED")
elif singleSave == "both":
    # Single File Save
    fileNameN = FileName + Run + '-alarmsTagged' + '.csv'
    eventSplice0.to_csv("main/" + fileNameN, index=False)
    print(fileNameN + " SAVED")
    
    # Split Dataframe into batches of 500K rows
    for counter in range(partitions):
        startPoint = counter * partionSize
        df_subset = eventSplice0.iloc[startPoint : (startPoint + partionSize)]
        #print(df_subset.info())

        # Save File
        fileNameN = "Subset File Ver/" + FileName + Run + '-' + str(counter).zfill(3) + '-alarmsTagged' + '.csv'
        df_subset.to_csv(fileNameN, index=False)
        print(fileNameN + " SAVED")
else:
    # Split Dataframe into batches of 500K rows
    for counter in range(partitions):
        startPoint = counter * partionSize
        df_subset = eventSplice0.iloc[startPoint : (startPoint + partionSize)]
        #print(df_subset.info())

        # Save File
        fileNameN = "Subset File Ver/" + FileName + Run + '-' + str(counter).zfill(3) + '-alarmsTagged' + '.csv'
        df_subset.to_csv(fileNameN, index=False)
        print(fileNameN + " SAVED")
        
# Ring Beeper When Complete
import winsound
import time

duration1 = 400  # milliseconds
freq1 = 400  # Hz
duration2 = 600  # milliseconds
freq2 = 300  # Hz
repeatCount = 7
for n in range(repeatCount):
    winsound.Beep(freq1, duration1)
    winsound.Beep(freq2, duration2)
    time.sleep(1)
# Out:
# Potential Train Events Raw-B0001-alarmsTagged.csv SAVED
# Subset File Ver/Potential Train Events Raw-B0001-000-alarmsTagged.csv SAVED
# Subset File Ver/Potential Train Events Raw-B0001-001-alarmsTagged.csv SAVED
# Subset File Ver/Potential Train Events Raw-B0001-002-alarmsTagged.csv SAVED
# Subset File Ver/Potential Train Events Raw-B0001-003-alarmsTagged.csv SAVED
# Subset File Ver/Potential Train Events Raw-B0001-004-alarmsTagged.csv SAVED
# Subset File Ver/Potential Train Events Raw-B0001-005-alarmsTagged.csv SAVED
# Subset File Ver/Potential Train Events Raw-B0001-006-alarmsTagged.csv SAVED
# Subset File Ver/Potential Train Events Raw-B0001-007-alarmsTagged.csv SAVED
