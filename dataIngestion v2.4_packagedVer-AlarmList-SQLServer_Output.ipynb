# %% [markdown]
# # Documentation
#
# ## Objective(s)
# 1. Ingest event log file data file into a consistent tabular format without error
# 2. Extract key features/attributes embedded in free text message log
# 3. Batch process the data to consolidate log files for easy of management
# 4. Due to the different table structure for EventList and AlarmList data (AlarmList has redundant fields removed), the preprocessing script cannot be used interchangeably when appending data to the SQL Server Table.

# %% [markdown]
# # Initialisation

# %% [markdown]
# ### Adjust Display Theme of Jupyter Notebook
# Optional Step
#
# Key Hotkeys:
# 1. Run cell: ctrl + enter
# 2. Delete Cell: DD
# 3. Undo Delete Cell: Z
# 4. Cut Cell: X
# 5. Copy Cell: C
# 6. Insert Cell Above: A
# 7. Insert Cell Below: B
# 8. Convert Cell to Code: Y
# 9. Convert Cell to Markdown: M

# %%
# install jupyterthemes
#!pip install jupyterthemes

# upgrade to latest version
#!pip install --upgrade jupyterthemes

# %%
#import jupyterthemes

# %%
# Adjust to Dark Theme
#jt -t chesterish

# %% [markdown]
# ## Load Libraries

# %%
#pip install --user --upgrade pandas

# %%
# Install a pip package in the current Jupyter kernel
import sys
#!{sys.executable} -m pip install schedule

# %%
# Import libraries
#import modin.pandas as pd
import pandas as pd
import numpy as np
import os
import pathlib
import datetime as dt
import time
import os # for manipulating file directories
import pyodbc # for sql operations
import sqlalchemy # for sql operations with pandas
import urllib # for defining sql connection parameters
import shutil # for transferring files between folders
#import re

# %% [markdown]
# ## Set Options

# %%
# Enable display of all columns for dataframes with many variables
pd.set_option('display.max_columns', None)

# %%
# Choose whether to initialise db from scratch or not
initDB = True

# %%
# Trigger SQL Function Test
testMode = True
# Use this to reset table data especially when running tests
resetTableData = True

# %% [markdown]
# ## Set Up Core Directories

# %%
# Check current directory location
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\scripts'

# %%
# Define root file directory folder where the files are being stored
#os.chdir(cwd + alarmLoc)
os.chdir(os.path.dirname(os.getcwd()) + '\\alarm-event-logs')

# Check current directory location
cwd = os.getcwd()

# Check directory location
cwd
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\alarm-event-logs'

# %%
# Create Directory for Output Files Generated
if not os.path.exists('dataCleaned'):
    os.makedirs('dataCleaned')
    
# Inspect files in directory
fileList = os.listdir()
fileList
# Out:
# ['associationRules',
#  'dataCleaned',
#  'desktop.ini',
#  'dummyLog',
#  'HISevent_data',
#  'Original Sample from 27 Oct 2020 (simplified).7z',
#  'Repair Logs',
#  'Sample from 27 Oct 2020 (OG).zip',
#  'sample_data_allServer _(Jan2021).7z',
#  'sample_data_allServer_raw&processed__(Jan2021).7z',
#  'sample_data_HISevent.7z',
#  'sample_data_test',
#  'taggedOutput',
#  'testLog',
#  'testOutput']

# %%
# Location of Alarm and Normal Event Files
alarmLoc = '\\sample_data_cms\\batch 001 - 20201230 to 20210201\\AlarmLogs'
eventLoc = '\\sample_data_cms\\batch 001 - 20201230 to 20210201\\EventLogs'
testLocAL = '\\sample_data_test\\batch 002\\AlarmLogs'
testLocAE = '\\sample_data_test\\batch 002\\EventLogs'

# Set variables
# Alarm Events: 'AL'  or 'TestAL' 
# All Events: 'AE' or 'TestAE' 

prefix = 'TestAL' 
batch = 'B001-'
serverEnv = 'CMS-'

# %% [markdown]
# ## Access Files to be Processed

# %%
# Define root file directory folder where the files are being stored
if prefix == "AL":
    os.chdir(cwd + alarmLoc)
    #os.chdir(cwd + eventLoc)
elif prefix == "AE":
    os.chdir(cwd + eventLoc)
elif prefix == "TestAL":
    os.chdir(cwd + testLocAL)
else:
    os.chdir(cwd + testLocAE)
    
# Check directory location
os.getcwd()
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\alarm-event-logs\\sample_data_test\\batch 002\\AlarmLogs'

# %%
# Get the list of all files in directory tree at given path
fileList = list()
for (dirpath, dirnames, filenames) in os.walk(os.getcwd()):
    fileList += [os.path.join(dirpath, file) for file in filenames] # use this if you want to append full URL
    #fileList += filenames
    
# Inspect data
len(fileList)
# Out:
# 762

# %%
testFile = fileList[0]
testFile
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\alarm-event-logs\\sample_data_test\\batch 002\\AlarmLogs\\AlarmListTest_1638320410_254559'

# %% [markdown]
# # Process Log Files

# %%
# Core Function for Cleaning (dependent on above functions)
# Excludes file saving
def cleaningScript_vector(fileInput, prefixInput = "TestAL", sqlServerExport = False):
    
    ##################################################################
    # Import Dependant Libraries
    ##################################################################
    
    import sys, os
    if 'pd' not in sys.modules:
        import pandas as pd
    if 'np' not in sys.modules:
        import numpy as np
    if 'dt' not in sys.modules:
        import datetime as dt
    #if 'os' not in sys.modules:
    #    import os as os
    
    ##################################################################
    # Initialise Dependant Function 1
    ##################################################################
    
    # Define function to remove free text message to facillitate formating later
    def replaceTextBetween1_series(originalTextSeries, delimeterA='Message:', delimterB='Theme:', replacementText=''):
        leadingText = originalTextSeries.str.split(delimeterA).str.get(0)
        trailingText = originalTextSeries.str.split(delimterB).str.get(1)

        return leadingText + replacementText + delimterB + trailingText
    
    
    ##################################################################
    # Initialise Dependant Function 2
    ##################################################################  
    
    def parseMessageField(originalTextSeries, delimeterA='Message:', delimterB='Theme:'):
        # Update v2.0
        # Remove leading delimiter (Delimiter A) from target string
        clip1 = originalTextSeries.str.split(delimeterA).str.get(1)
        # Remove lagging delimiter (Delimiter B) from target string
        clip2 = clip1.str.split(delimterB).str.get(0).str.strip()
        # Clean and split target string into constituent components
        clip3 = clip2.str.replace(";", "").str.split("$")
        
        
        # Delete redundant fields
        del clip1, clip2
        
        # Extract ASSET_ID_RAW from 1st Component of Clip 3
        ASSET_ID_RAW = clip3.str.get(0).str.strip()
        
        # Extract ASSET_DESCRIPTION from 2nd Component of Clip 3, a may be further delimited by a colon sign
        try:
            ASSET_DESCRIPTION = clip3.str.get(1).str.split(": ").str.get(0).str.strip()
        except: 
            ASSET_DESCRIPTION = None
        
         # Extract EVENT_DESCRIPTION from 2nd Component of Clip 3, a may be further delimited by a colon sign
        try:    
            EVENT_DESCRIPTION = clip3.str.get(1).str.split(": ").str.get(1).str.strip()
        except:
            EVENT_DESCRIPTION = None
        
         # Extract EVENT_STATUS from 3rd Component of Clip 3
        try:
            EVENT_STATUS = clip3.str.get(2).str.strip()
        except:
            EVENT_STATUS = None
        
        # Extract OPERATOR_INITIALS from 4th Component of Clip 4
        try:
            OPERATOR_INITIALS = clip3.str.get(3).str.strip()
        except:
            OPERATOR_INITIALS = None

        return ASSET_ID_RAW, ASSET_DESCRIPTION, EVENT_DESCRIPTION, EVENT_STATUS, OPERATOR_INITIALS
    
    ##################################################################
    # Initialise Dependant Function 3
    ##################################################################
    
    def parseMetaData(f_meta1, f_meta2):

        # Pre-process f_meta1
        f_meta1 = f_meta1.split('\n')[0].split('Begin Notification: ')[1].split(' ')

        # Pre-process f_meta2
        f_meta2 = f_meta2.split('End Notification: ')[1]

        # Get DATETIME_SEND
        DATETIME_SENT = str(f_meta1[0]) + ' ' + str(f_meta1[1])

        # Get TimeCode
        TIME_CODE = str(f_meta1[2]) + '.' + str(f_meta1[3])
        TIME_CODE2 = str(f_meta1[2]) + str(f_meta1[3])

        # Get DATETIME_RECEIVED
        DATETIME_RECEIVED = f_meta2

        return DATETIME_SENT, DATETIME_RECEIVED, TIME_CODE
    
    
    ##################################################################
    # Initialise Function
    ##################################################################
    
    # Define All Column Names (Especially for cases with an empty dataframe)
    col_names = [
                'ENTRY_CODE_SUFFIX', #00
                'ENTRY_CODE', #01
                'ALARM_ID', #02
                'USER_ID', #03
                'EQUIPMENT_NAME', #04
                'VALUE', #05
                'VALUE_STATE', #06
                'ACKNOWLEDGEMENT_REQUIRED', #07
                'SEVERITY', #08
                'HIDDEN', #09
                'THEME', #10
                'EQUIPMENT_DATE',  #11
                'ACQUISITION_DATE',  #12
                'SCS_TIME', #13
                'FUNCTIONAL_CATEGORY', #14
                'GEOGRAPHICAL_CATEGORY', #15
                'ENVIRONMENT', #16
                'USER1', #17
                'ASSET_ID_RAW', #18
                'ASSET_DESCRIPTION', #19
                'EVENT_DESCRIPTION', #20
                'EVENT_STATUS', #21
                'OPERATOR_INITIALS' #22
                ]
    
    # Define Attribute Names for Header (main body excluding metadata)
    headerList_core = [              
                      'ENTRY_CODE_RAW', #0
                      'ENTRY_CODE_SUFFIX', #1
                      'ENTRY_CODE', #2
                      'ALARM_ID', #3
                      'AUTO_ID', #4
                      'USER_ID', #5
                      'EQUIPMENT_NAME', #0
                      'VALUE', #7
                      'VALUE_STATE', #8
                      'ACKNOWLEDGEMENT_REQUIRED', #9
                      'SEVERITY', #10
                      'SHELVE', #11
                      'HIDDEN', #12
                      'THEME', #13
                      #'MESSAGE', #XX
                      'EQUIPMENT_DATE', #14
                      'EQUIPMENT_DATE0', #15
                      'ACQUISITION_DATE', #16
                      'ACQUISITION_DATE0', #17
                      'SCS_TIME', #18
                      'SCS_TIME0', #19
                      'FUNCTIONAL_CATEGORY', #20
                      'GEOGRAPHICAL_CATEGORY', #21
                      'ACKNOWLEDGEMENT_AUTOPOINTER', #22
                      'ENVIRONMENT', #23
                      'USER1', #24
                      'USER2', #25
                      'DSS_EVENT_TYPE' #26
                 ]
     
    ##################################################################
    # Ingest File
    ##################################################################
    
    # Define File Name
    fileName = fileInput
    
    # Read in file
    file = open(fileName, 'r')
        
    # Convert file contents to a list
    fileContents = list(file)

    # Close file
    file.close()

               
    ##################################################################
    # Extract Key Components in Ingested File
    ##################################################################
    
    # Extract row containing meta data of file sent datetime
    f_meta1 = fileContents[1]
    
    # Extract row containing meta data of file received datetime
    f_meta2 = fileContents[-1]
        
    # Remove redundant list elements
    del fileContents[0:3], fileContents[-1]
    
    # Error catch if this is the first log instance (empty log)
    if (f_meta1.find("first notification on online") > -1):
        # Create an Empty Dataframe with all the headers to match other dataframes to be appended
        df = pd.DataFrame(columns = col_names)
        
        # Delete redundant variables
        del f_meta1, f_meta2
    else:  
        # Load File
        df = pd.DataFrame(fileContents,columns=['rawData'])
        #print(df["rawData"][0])
        
        #print(ASSET_ID_RAW)
        #ASSET_ID_RAW = ASSET_ID_RAW.str.encode('ascii', 'ignore').str.decode() # TEST
        
        
        ##################################################################
        # Process Main Body (Exclude Free Text Message Field)
        ##################################################################
        
        # Exception handling for cases where the log entries are corrupted and split into 2 rows per entry
        # instead of the usual single row;
        # these cases tend to have a substring of unicode special characters marking the breakpoints

        # corruption check
        df["rawData"] = df["rawData"].str.strip() # remove non-printable char in string
        check_val_head = sum(df["rawData"].str.endswith("(.UàÑ"))
        check_val_tail = sum(df["rawData"].str.startswith("º÷"))
        
        print(check_val_head)
        print(check_val_tail)
        
        if (check_val_head == check_val_tail) & (check_val_head > 0) & (check_val_tail > 0):
            # If event log entry is corrupted, do this...
            
            # Separate breakpoint 1
            df_head = df.loc[df["rawData"].str.endswith("(.UàÑ")].copy()
            
            #print(df_head["rawData"][0])
            df_head["rawData"] = df_head["rawData"].str.split(pat = ".UàÑ", n = 1, expand = True)[0]
            df_head["rawData"] = df_head["rawData"].str.replace(pat = ";(", repl = "", regex = False)
            #df_head["rawData"] = df_head["rawData"].str.replace("(.UàÑ", regex = False)
            
            # Separate breakpoint 2
            df_tail = df.loc[df["rawData"].str.startswith("º÷")].copy()
            # drop first 3 char which has the unicode substring, direct targeting is not possible as that throws an error
            df_tail["rawData"] = df_tail["rawData"].str[3:] 
            
            # Reset index of dataframes
            df_head = df_head.copy().reset_index()
            df_tail = df_tail.copy().reset_index()
            
            # Join and repair corrupted entries which has been broken up into 2 rows
            df_head = df_head["rawData"] + df_tail["rawData"]

            # Filter out corrupted entires
            df = df.loc[(df["rawData"].str.endswith("(.UàÑ") == False)].copy()
            df = df.loc[(df["rawData"].str.startswith("º÷") == False)].copy()
            df = df.squeeze()
                        
            # Add back repaired corrupted entries
            df = df.append(df_head, ignore_index=True)
            df = pd.DataFrame(df, columns = ['rawData'])
            
            # Delete redundant variables
            del df_head, df_tail
            
            # Remove free text string "message" from log string
            df['text0'] = replaceTextBetween1_series(df["rawData"])
            
        else:
            # If event log entry is ok, do this...
            
            # Remove free text string "message" from log string
            df['text0'] = replaceTextBetween1_series(df["rawData"])
        
        # Delete redundant variables
        del check_val_head, check_val_tail
        
        # Delimit Columns
        df[headerList_core] = df['text0'].str.split(expand = True)

        # Merge Date and Time columns
        df['EQUIPMENT_DATE'] = df['EQUIPMENT_DATE'] + "." + df['EQUIPMENT_DATE0'].astype(str)
        df['ACQUISITION_DATE'] = df['ACQUISITION_DATE'] + "." + df['ACQUISITION_DATE0'].astype(str)
        df['SCS_TIME'] = df['SCS_TIME'] + "." + df['SCS_TIME0'].astype(str)
        
        # Extract Entry Code Suffix
        df['ENTRY_CODE_SUFFIX'] = df["ENTRY_CODE_RAW"].str.extract(r"\(""([+|=|-])")

        # Drop redundant columns
        df = df.drop(columns=['ENTRY_CODE_RAW', 
                              'EQUIPMENT_DATE0', 
                              'ACQUISITION_DATE0', 
                              'SCS_TIME0', 
                              'text0'])

        # Clean up values of each row by removing variable name prefixed to each value
        n = 3
        nEnd = df.shape[1]

        #df.iloc[::,n] = df.iloc[::,n].str.split(':', expand = True)[1]
        while (n < nEnd):
            df.iloc[::,n] = df.iloc[::,n].str.split(':', n = 1, expand = True)[1]
            n = n + 1

        # Delete redundant variables
        del n, nEnd

        # Drop redundant entries caused by entry deletion due to server memory limitations
        # Marked by "-" suffix in ["ENTRY_CODE_SUFFIX"]
        df = df.loc[df['ENTRY_CODE_SUFFIX'] != "-"].reset_index(drop=True)
        
        
        ##################################################################
        # Check if the remaining dataframe is empty or not
        ##################################################################

        if df.shape[0] == 0:
            #print("Empty Dataframe " + fileName)
            # Create an Empty Dataframe with all the headers to match other dataframes to be appended
            df  = pd.DataFrame(columns = col_names) 
        else:
            #print("Continue file processing")


            ##################################################################
            # Process Free Text Message Field
            ##################################################################

            # Remove free text string "message" from log string
            #del df['MESSAGE']
                        
            # Parse Free Text Message Log
            
            df["ASSET_ID_RAW"], df["ASSET_DESCRIPTION"], df["EVENT_DESCRIPTION"], df["EVENT_STATUS"], df["OPERATOR_INITIALS"] = parseMessageField(df["rawData"])
            
            ###############################################################
    
            # Reorder values of exception cases of EVENT_DESCRIPTION and ASSET_DESCRIPTION
            # EVENT_DESCRIPTION is prioritised
            try:
                df.loc[((df["EVENT_DESCRIPTION"] == None) | 
                       (df["EVENT_DESCRIPTION"] == "") | 
                       df["EVENT_DESCRIPTION"].isna()), 
                       "EVENT_DESCRIPTION"] = df["ASSET_DESCRIPTION"]

                df.loc[(df["EVENT_DESCRIPTION"] == df["ASSET_DESCRIPTION"]), 
                       "ASSET_DESCRIPTION"] = None                
            except:
                pass

            ###############################################################
            # Clean up for "GWS Broadcast" - Guess ASSET_DESCRIPTION based on EVENT_DESCRIPTION
            try:
                df.loc[(df["EVENT_DESCRIPTION"].str.contains("msg", na = False, regex = False)) & 
                       (df["EVENT_DESCRIPTION"].str.contains("Gws", na = False, regex = False)), "ASSET_DESCRIPTION"] = "GWS Broadcast"
            except:
                pass  

            ###############################################################
            # Clean up for "NelVisu" - Guess ASSET_DESCRIPTION based on EVENT_DESCRIPTION
            try:
                df.loc[(df["EVENT_DESCRIPTION"].str.contains("NelVisu", na = False, regex = False)), "ASSET_DESCRIPTION"] = "NelVisu"
            except:
                pass

            ###############################################################
            # Clean up for "Train Radio" - Guess ASSET_DESCRIPTION based on EVENT_DESCRIPTION
            try:
                df.loc[(df["EVENT_DESCRIPTION"].str.contains("TR___", na = False, regex = False)) &
                       (df["EVENT_DESCRIPTION"].str.contains("radio", na = False, regex = False)), "ASSET_DESCRIPTION"] = "Train Radio"
            except:
                pass

            ###############################################################
            # Clean up for "Trainborne Camera" - Guess ASSET_DESCRIPTION based on EVENT_DESCRIPTION
            try:
                df.loc[(df["EVENT_DESCRIPTION"].str.contains("Trainborne Camera", na = False, regex = False)), "ASSET_DESCRIPTION"] = "Trainborne Camera"
            except:
                pass

            ###############################################################
            # Clean up for "Trainborne Quad" - Guess ASSET_DESCRIPTION based on EVENT_DESCRIPTION
            try:
                df.loc[(df["EVENT_DESCRIPTION"].str.contains("Trainborne Quad", na = False, regex = False)), "ASSET_DESCRIPTION"] = "Trainborne Quad"
            except:
                pass

            ###############################################################
            # Clean up for "Tunnel Light" - Guess ASSET_DESCRIPTION based on EVENT_DESCRIPTION
            try:
                df.loc[(df["EVENT_DESCRIPTION"].str.contains("Tunnel Light", na = False, regex = False)) & 
                        ((df["ASSET_DESCRIPTION"].isna()) | 
                         (df["ASSET_DESCRIPTION"] == None) | 
                         (df["ASSET_DESCRIPTION"] == "")), "ASSET_DESCRIPTION"] = "Tunnel LTG"
            except:
                pass   

            ###############################################################
            # Clean up for "Control Take Over" - Guess ASSET_DESCRIPTION based on EVENT_DESCRIPTION
            try:
                df.loc[(df["EVENT_DESCRIPTION"].str.contains("Control Take Over for", na = False, regex = False)), "ASSET_DESCRIPTION"] = df["EVENT_DESCRIPTION"].str.extract(r"Control Take Over for (\w+) ")
                
            except:
                pass
            
            ###############################################################
            # Clean up for "Close Control" - Guess ASSET_DESCRIPTION based on EVENT_DESCRIPTION
            try:
                df.loc[(df["EVENT_DESCRIPTION"].str.contains("Close Control", na = False, regex = False)) & 
                      ((df["ASSET_DESCRIPTION"].isna()) | 
                       (df["ASSET_DESCRIPTION"] == None) | 
                       (df["ASSET_DESCRIPTION"] == "")
                      ), "ASSET_DESCRIPTION"] = "Traction Control"
            except:
                pass    

            ##################################################################
            # Format Data Type & Perform Final Clean Up
            ################################################################## 
            
            # Delete redundant variables (update 2.0)
            del df["rawData"]
            
            # Clean up operator initials (Update v2.0)
            try:
                df.loc[df["OPERATOR_INITIALS"].str.contains("(", na=False, regex=False), "OPERATOR_INITIALS"] = np.nan
            except:
                pass
            
            
            # Standardise null values
            df = df.replace("", np.nan).fillna(value=np.nan)          
            
            # Preliminary Formatting
            df = df.convert_dtypes()
            
            # Convert binary values to Boolean True/False
            try:
                df.loc[df["ACKNOWLEDGEMENT_REQUIRED"] == 0,"ACKNOWLEDGEMENT_REQUIRED"] = False
            except:
                pass
            try:
                df.loc[df["ACKNOWLEDGEMENT_REQUIRED"] == 1, "ACKNOWLEDGEMENT_REQUIRED"] = True
            except:
                pass
            
            try:
                df.loc[df["HIDDEN"] == 0, "HIDDEN"] = False
            except:
                pass            
            try:
                df.loc[df["HIDDEN"] == 1, "HIDDEN"] = True
            except:
                pass
            
            # Check data types
            df.dtypes# Preliminary Formatting
            df = df.convert_dtypes()

            # Format fields
            #df[''] = df[''].astype('')
            convert_dict = {'ALARM_ID': 'str',
                            'AUTO_ID': 'str',
                            'USER_ID': 'str',
                            'VALUE': 'str',
                            'VALUE_STATE': 'category',
                            'ACKNOWLEDGEMENT_REQUIRED': 'bool',
                            'SEVERITY': 'category',
                            'SHELVE': 'category',
                            'HIDDEN': 'bool',
                            'THEME': 'category',
                            'FUNCTIONAL_CATEGORY': 'category',
                            'GEOGRAPHICAL_CATEGORY': 'category',
                            'EQUIPMENT_DATE': 'float',
                            'ACQUISITION_DATE': 'float',
                            'SCS_TIME': 'float',
                            'ASSET_ID_RAW': 'str',
                            'ASSET_DESCRIPTION': 'str',
                            'EVENT_DESCRIPTION': 'str',
                            'EVENT_STATUS': 'category',
                            'OPERATOR_INITIALS': 'str'
                           }
            df = df.astype(convert_dict)

            # Delete redundant variables
            del convert_dict

            
            # This code block could be redundant as the fields are not being used
            # Format Unix Time Values to Datetime Format in Local Time (GMT+8)
            # 19 digits unix time (without decimal place): nanosecond resolution (ns)
            # 16 digits unix time (without decimal place): microsecond resolution (us)
            # 13 digits unix time (without decimal place): millisecond resolution (ms)
            # 10 digits unix time (without decimal place): second resolution (s)
            # The values seem to be 9 hours behind (standard unix time should be pegged to GMT)
            timeAdjust = 8
            df['EQUIPMENT_DATE'] = pd.to_datetime(df['EQUIPMENT_DATE'], unit='s') + pd.Timedelta(hours = timeAdjust)
            df['ACQUISITION_DATE'] = pd.to_datetime(df['ACQUISITION_DATE'], unit='s') + pd.Timedelta(hours = timeAdjust)
            df['SCS_TIME'] = pd.to_datetime(df['SCS_TIME'], unit='s') + pd.Timedelta(hours = timeAdjust)
            
            # Drop redundant columns
            df = df.drop(columns=[
                                    'AUTO_ID', 
                                    'SHELVE', 
                                    #'EQUIPMENT_DATE', 
                                    #'ACQUISITION_DATE', 
                                    #'SCS_TIME', 
                                    'ACKNOWLEDGEMENT_AUTOPOINTER', 
                                    'USER2', 
                                    'DSS_EVENT_TYPE'
                                   ])
            
    # Preliminary tagging of alarm events
    if (prefixInput == "AL") | (prefixInput == "TestAL"):
        df["isAlarm"] = True
    else:
        df["isAlarm"] = False
        
    # Convert boolean values to 1 and 0 for SQL Server Export
    if sqlServerExport == True:
        df["ACKNOWLEDGEMENT_REQUIRED"] = df["ACKNOWLEDGEMENT_REQUIRED"].astype(int)
        df["HIDDEN"] = df["HIDDEN"].astype(int)
        df["isAlarm"] = df["isAlarm"].astype(int)
    else:
        pass     
        

    ##################################################################
    # End
    ##################################################################
    
    return df

# %%
# Start clock to measure time taken
startTime = time.time()

testDF=cleaningScript_vector(testFile, prefix)

# End clock to measure time taken
executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
print('Execution time in minutes: ' + str(executionTime/60))
print('Execution time in hours: ' + str(executionTime/60/60))
# Out:
# 0
# 0
# Execution time in seconds: 0.05099773406982422
# Execution time in minutes: 0.0008499622344970703
# Execution time in hours: 1.4166037241617838e-05

# %%
testDF.head()
# Out:
#   ENTRY_CODE_SUFFIX ENTRY_CODE ALARM_ID USER_ID                EQUIPMENT_NAME  \
# 0                 =      53894    53894       0  :BGK:BMF:PMSA_0001:PLC1_0003
#
#   VALUE VALUE_STATE  ACKNOWLEDGEMENT_REQUIRED SEVERITY  HIDDEN THEME  \
# 0     1           0                      True        2    True     0
#
#                  EQUIPMENT_DATE              ACQUISITION_DATE  \
# 0 2021-12-01 09:00:09.830429952 2021-12-01 09:00:09.830429952
#
#                        SCS_TIME FUNCTIONAL_CATEGORY GEOGRAPHICAL_CATEGORY  \
# 0 2021-12-01 09:00:09.830429952                  51                    17
#
#   ENVIRONMENT USER1      ASSET_ID_RAW ASSET_DESCRIPTION EVENT_DESCRIPTION  \
# 0      OCCCMS     1  SCS/BGK/B1/PLC03    BGK ISCS PLC 3     Mux Selection
#
#   EVENT_STATUS OPERATOR_INITIALS  isAlarm
# 0       NORMAL              <NA>     True

# %%
print(testDF.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENTRY_CODE_SUFFIX         1 non-null      string
#  1   ENTRY_CODE                1 non-null      string
#  2   ALARM_ID                  1 non-null      object
#  3   USER_ID                   1 non-null      object
#  4   EQUIPMENT_NAME            1 non-null      string
#  5   VALUE                     1 non-null      object
#  6   VALUE_STATE               1 non-null      category
#  7   ACKNOWLEDGEMENT_REQUIRED  1 non-null      bool
#  8   SEVERITY                  1 non-null      category
#  9   HIDDEN                    1 non-null      bool
#  10  THEME                     1 non-null      category
#  11  EQUIPMENT_DATE            1 non-null      datetime64[ns]
#  12  ACQUISITION_DATE          1 non-null      datetime64[ns]
#  13  SCS_TIME                  1 non-null      datetime64[ns]
#  14  FUNCTIONAL_CATEGORY       1 non-null      category
#  15  GEOGRAPHICAL_CATEGORY     1 non-null      category
#  16  ENVIRONMENT               1 non-null      string
#  17  USER1                     1 non-null      string
#  18  ASSET_ID_RAW              1 non-null      object
#  19  ASSET_DESCRIPTION         1 non-null      object
#  20  EVENT_DESCRIPTION         1 non-null      object
#  21  EVENT_STATUS              1 non-null      category
#  22  OPERATOR_INITIALS         1 non-null      object
#  23  isAlarm                   1 non-null      bool
# dtypes: bool(3), category(6), datetime64[ns](3), object(7), string(5)
# memory usage: 953.0+ bytes
# None

# %%
testDF["VALUE"]
# Out:
# 0    1
# Name: VALUE, dtype: object

# %%
testFile2 = fileList[1]
testFile2

# Start clock to measure time taken
startTime = time.time()

testDF=cleaningScript_vector(testFile2, prefix)

# End clock to measure time taken
executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))
print('Execution time in minutes: ' + str(executionTime/60))
print('Execution time in hours: ' + str(executionTime/60/60))
# Out:
# 0
# 0
# Execution time in seconds: 0.05299973487854004
# Execution time in minutes: 0.0008833289146423339
# Execution time in hours: 1.4722148577372232e-05

# %%
testFile2
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\alarm-event-logs\\sample_data_test\\batch 002\\AlarmLogs\\AlarmListTest_1638320436_251896'

# %%
testFile
# Out:
# 'C:\\Users\\cftfda01\\Documents\\SBST Train IAMS Project\\alarm-event-logs\\sample_data_test\\batch 002\\AlarmLogs\\AlarmListTest_1638320410_254559'

# %%
testDF.head()
# Out:
#   ENTRY_CODE_SUFFIX ENTRY_CODE ALARM_ID USER_ID                EQUIPMENT_NAME  \
# 0                 =      53983    53983       0  :BGK:BMF:PMSA_0001:PLC1_0002
#
#   VALUE VALUE_STATE  ACKNOWLEDGEMENT_REQUIRED SEVERITY  HIDDEN THEME  \
# 0     0           1                      True        2    True     0
#
#                  EQUIPMENT_DATE              ACQUISITION_DATE  \
# 0 2021-12-01 09:00:36.869270016 2021-12-01 09:00:36.869270016
#
#                        SCS_TIME FUNCTIONAL_CATEGORY GEOGRAPHICAL_CATEGORY  \
# 0 2021-12-01 09:00:36.869270016                  51                    17
#
#   ENVIRONMENT USER1      ASSET_ID_RAW ASSET_DESCRIPTION EVENT_DESCRIPTION  \
# 0      OCCCMS     1  SCS/BGK/B1/PLC02    BGK ISCS PLC 2     Mux Selection
#
#   EVENT_STATUS OPERATOR_INITIALS  isAlarm
# 0        FAULT              <NA>     True

# %%
print(testDF.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENTRY_CODE_SUFFIX         1 non-null      string
#  1   ENTRY_CODE                1 non-null      string
#  2   ALARM_ID                  1 non-null      object
#  3   USER_ID                   1 non-null      object
#  4   EQUIPMENT_NAME            1 non-null      string
#  5   VALUE                     1 non-null      object
#  6   VALUE_STATE               1 non-null      category
#  7   ACKNOWLEDGEMENT_REQUIRED  1 non-null      bool
#  8   SEVERITY                  1 non-null      category
#  9   HIDDEN                    1 non-null      bool
#  10  THEME                     1 non-null      category
#  11  EQUIPMENT_DATE            1 non-null      datetime64[ns]
#  12  ACQUISITION_DATE          1 non-null      datetime64[ns]
#  13  SCS_TIME                  1 non-null      datetime64[ns]
#  14  FUNCTIONAL_CATEGORY       1 non-null      category
#  15  GEOGRAPHICAL_CATEGORY     1 non-null      category
#  16  ENVIRONMENT               1 non-null      string
#  17  USER1                     1 non-null      string
#  18  ASSET_ID_RAW              1 non-null      object
#  19  ASSET_DESCRIPTION         1 non-null      object
#  20  EVENT_DESCRIPTION         1 non-null      object
#  21  EVENT_STATUS              1 non-null      category
#  22  OPERATOR_INITIALS         1 non-null      object
#  23  isAlarm                   1 non-null      bool
# dtypes: bool(3), category(6), datetime64[ns](3), object(7), string(5)
# memory usage: 953.0+ bytes
# None

# %% [markdown]
# ## Set Up SQL Server Database & Functions
# The goal is to dump the pre-processed file into a SQL Server Database where further operations may then be made to perform the alarm tagging and nuisance event tagging. But first we will need to set up the SQL Server Database.
#
# ** Key tables **
# 1. EventList Table
# 2. AlarmList Table
# 3. Output_AlarmTagged Table
# 4. Output_TagComplete Table

# %%
# Open a database connection to target database
# All subsequent functions will depend on this connection
# Remember to close connection when done
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=SBSR-RD-0K00200;'
                      'Database=IAMS_DBtest;'
                      'Trusted_Connection=yes;')

# Define Server Parameters to Initiate Connection Engine via SQL Alchemy
# This has the same values as the connection request
# Only if one uses the windows authentification method
# Otherwise, one will need to define "UID" (user ID) + "PWD" (password)
serverParams = urllib.parse.quote_plus('Driver={SQL Server};'
                                       'Server=SBSR-RD-0K00200;'
                                       'Database=IAMS_DBtest;'
                                       'Trusted_Connection=yes;'
                                       #"UID=user;"
                                       #"PWD=password"
                                      )

# Create cursor to work in database
# SQL auto commits transactions
cursor = conn.cursor()

# %%
# Initialise tables (empty)
if initDB == True:
    # Initialise eventList Table
    cursor.execute('''
                if not exists (select * from sys.tables where name='eventList')
                    CREATE TABLE eventList (
                        ENTRY_CODE_SUFFIX varchar(255) null, 
                        ENTRY_CODE varchar(255) null,
                        ALARM_ID varchar(255) null,
                        USER_ID varchar(255) null,
                        EQUIPMENT_NAME varchar(255) null,
                        VALUE varchar(255) null,
                        VALUE_STATE varchar(255) null,
                        ACKNOWLEDGEMENT_REQUIRED int null,
                        SEVERITY varchar(255) null,
                        HIDDEN int null,
                        THEME varchar(255) null,
                        EQUIPMENT_DATE datetime null,
                        ACQUISITION_DATE datetime null,
                        SCS_TIME datetime null,
                        FUNCTIONAL_CATEGORY varchar(255) null,
                        GEOGRAPHICAL_CATEGORY varchar(255) null,
                        ENVIRONMENT varchar(255) null,
                        USER1 varchar(255) null,
                        ASSET_ID_RAW varchar(255) null,
                        ASSET_DESCRIPTION varchar(255) null,
                        EVENT_DESCRIPTION varchar(255) null,
                        EVENT_STATUS varchar(255) null,
                        OPERATOR_INITIALS varchar(255) null,
                        ASSET_DESC_CAT varchar(255) null,
                        EVENT_DESC_CAT varchar(255) null,
                        TrainID varchar(255) null,
                        CarID varchar(255) null,
                        ServiceID varchar(255) null,
                        AssetClass varchar(255) null,
                        AssetSubClass varchar(255) null,
                        DATETIME_SENT datetime null,
                        DATETIME_RECEIVED datetime null,
                        TIME_CODE datetime null,
                        isAlarm int null,
                        DATETIME_LOADED DATETIME NULL DEFAULT(GETDATE())
                    )
                    ''')
    
    # Initialise alarmList Table
    cursor.execute('''
                if not exists (select * from sys.tables where name='alarmList')
                    CREATE TABLE alarmList (
                        ENTRY_CODE_SUFFIX varchar(255) null, 
                        ENTRY_CODE varchar(255) null,
                        ALARM_ID varchar(255) null,
                        USER_ID varchar(255) null,
                        EQUIPMENT_NAME varchar(255) null,
                        VALUE varchar(255) null,
                        VALUE_STATE varchar(255) null,
                        ACKNOWLEDGEMENT_REQUIRED varchar(255) null,
                        SEVERITY varchar(255) null,
                        HIDDEN int null,
                        THEME varchar(255) null,
                        EQUIPMENT_DATE datetime null,
                        ACQUISITION_DATE datetime null,
                        SCS_TIME datetime null,
                        FUNCTIONAL_CATEGORY varchar(255) null,
                        GEOGRAPHICAL_CATEGORY varchar(255) null,
                        ENVIRONMENT varchar(255) null,
                        USER1 varchar(255) null,
                        ASSET_ID_RAW varchar(255) null,
                        ASSET_DESCRIPTION varchar(255) null,
                        EVENT_DESCRIPTION varchar(255) null,
                        EVENT_STATUS varchar(255) null,
                        OPERATOR_INITIALS varchar(255) null,
                        isAlarm int null,
                        DATETIME_LOADED DATETIME NULL DEFAULT(GETDATE())
                    )
                    ''')
    
    # Initialise Output_AlarmTagged Table
    cursor.execute('''
                if not exists (select * from sys.tables where name='Output_AlarmTagged')
                    CREATE TABLE Output_AlarmTagged (
                        ENTRY_CODE_SUFFIX varchar(255) null, 
                        ENTRY_CODE varchar(255) null,
                        ALARM_ID varchar(255) null,
                        USER_ID varchar(255) null,
                        EQUIPMENT_NAME varchar(255) null,
                        VALUE varchar(255) null,
                        VALUE_STATE varchar(255) null,
                        ACKNOWLEDGEMENT_REQUIRED int null,
                        SEVERITY varchar(255) null,
                        HIDDEN int null,
                        THEME varchar(255) null,
                        EQUIPMENT_DATE datetime null,
                        ACQUISITION_DATE datetime null,
                        SCS_TIME datetime null,
                        FUNCTIONAL_CATEGORY varchar(255) null,
                        GEOGRAPHICAL_CATEGORY varchar(255) null,
                        ENVIRONMENT varchar(255) null,
                        USER1 varchar(255) null,
                        ASSET_ID_RAW varchar(255) null,
                        ASSET_DESCRIPTION varchar(255) null,
                        EVENT_DESCRIPTION varchar(255) null,
                        EVENT_STATUS varchar(255) null,
                        OPERATOR_INITIALS varchar(255) null,
                        ASSET_DESC_CAT varchar(255) null,
                        EVENT_DESC_CAT varchar(255) null,
                        TrainID varchar(255) null,
                        CarID varchar(255) null,
                        ServiceID varchar(255) null,
                        AssetClass varchar(255) null,
                        AssetSubClass varchar(255) null,
                        DATETIME_SENT datetime null,
                        DATETIME_RECEIVED datetime null,
                        TIME_CODE datetime null,
                        isAlarm int null,
                        DATETIME_LOADED DATETIME NULL DEFAULT(GETDATE())
                    )
                    ''')
    
    # Initialise Output_TagComplete
    cursor.execute('''
                if not exists (select * from sys.tables where name='Output_TagComplete')
                    CREATE TABLE Output_TagComplete (
                        ENTRY_CODE_SUFFIX varchar(255) null, 
                        ENTRY_CODE varchar(255) null,
                        ALARM_ID varchar(255) null,
                        USER_ID varchar(255) null,
                        EQUIPMENT_NAME varchar(255) null,
                        VALUE varchar(255) null,
                        VALUE_STATE varchar(255) null,
                        ACKNOWLEDGEMENT_REQUIRED int null,
                        SEVERITY varchar(255) null,
                        HIDDEN int null,
                        THEME varchar(255) null,
                        EQUIPMENT_DATE datetime null,
                        ACQUISITION_DATE datetime null,
                        SCS_TIME datetime null,
                        FUNCTIONAL_CATEGORY varchar(255) null,
                        GEOGRAPHICAL_CATEGORY varchar(255) null,
                        ENVIRONMENT varchar(255) null,
                        USER1 varchar(255) null,
                        ASSET_ID_RAW varchar(255) null,
                        ASSET_DESCRIPTION varchar(255) null,
                        EVENT_DESCRIPTION varchar(255) null,
                        EVENT_STATUS varchar(255) null,
                        OPERATOR_INITIALS varchar(255) null,
                        ASSET_DESC_CAT varchar(255) null,
                        EVENT_DESC_CAT varchar(255) null,
                        TrainID varchar(255) null,
                        CarID varchar(255) null,
                        ServiceID varchar(255) null,
                        AssetClass varchar(255) null,
                        AssetSubClass varchar(255) null,
                        DATETIME_SENT datetime null,
                        DATETIME_RECEIVED datetime null,
                        TIME_CODE datetime null,
                        isAlarm int null,
                        DATETIME_LOADED DATETIME NULL DEFAULT(GETDATE()),
                        RepeatAlarm int null,
                        AltAlarm2 int null,
                        AltAlarm3 int null,
                        NuisanceAlarm int null
                    )
                    ''')
    
    # Initialise TestValues_Master Table
    cursor.execute('''
                if not exists (select * from sys.tables where name='TestValues_Master')
                    CREATE TABLE TestValues_Master (
                        eventID int null, 
                        DATEANDTIME datetime null,
                        eventDesc text null,
                        TnF int null,
                        blanCol int null,
                        DATETIME_LOADED DATETIME NULL DEFAULT(GETDATE())
                    )
                    ''')
    # Initialise TestValues_Alarm Table
    cursor.execute('''
                if not exists (select * from sys.tables where name='TestValues_Alarm')
                    CREATE TABLE TestValues_Alarm (
                        eventID int null, 
                        DATEANDTIME datetime null,
                        eventDesc text null,
                        TnF int null,
                        blanCol int null,
                        DATETIME_LOADED DATETIME NULL DEFAULT(GETDATE())
                    )
                    ''')
    # Initialise Test_AlarmTagged Table
    cursor.execute('''
                if not exists (select * from sys.tables where name='Test_AlarmTagged')
                    CREATE TABLE Test_AlarmTagged (
                        eventID int null, 
                        DATEANDTIME datetime null,
                        eventDesc text null,
                        TnF int null,
                        blanCol int null,
                        DATETIME_LOADED DATETIME NULL DEFAULT(GETDATE())
                    )
                    ''')
    # Initialise Test_Final Table
    cursor.execute('''
                if not exists (select * from sys.tables where name='Test_Final')
                    CREATE TABLE Test_Final (
                        eventID int null, 
                        DATEANDTIME datetime null,
                        eventDesc text null,
                        TnF int null,
                        blanCol int null,
                        DATETIME_LOADED DATETIME NULL DEFAULT(GETDATE()),
                        RepeatAlarm int null, 
                        ToggleEventA int null, 
                        ToggleEventB int null, 
                        NuisanceAlarm int null
                    )
                    ''')
    
    
    conn.commit()
else:
    pass

# %%
# Function to Inspect All Tables
def list_dbTables():
    # Check list of tables in db
    cursor.execute("SELECT table_name FROM INFORMATION_SCHEMA.TABLES ")
    print(cursor.fetchall())

# List tables in database
# Note: %memit" prefix is used to log peak memory uage
list_dbTables()
# Out:
# [('eventList', ), ('alarmList', ), ('Output_AlarmTagged', ), ('Output_TagComplete', ), ('AppendTest', ), ('CompareTest', )]

# %%
# Function to list contents in target table
def list_tableContents(targetTable, rowLimit = 10):
    # Gets first n rows (rowLimit) from target table sorted by datetime (oldest entry first)
    # Not allowed to get all values as the table size can be huge
    cursor.execute(f"SELECT top {rowLimit} * FROM {targetTable} ORDER BY 'DATEANDTIME' ASC")
    results = cursor.fetchall()
    print(targetTable, "Contents")
    counter = 0
    print("Table Values")
    print("---START---")
    for row in results:
        counter=counter+1
        print(counter, row)
    print("---END---")

# Define the target table
# This table will be where the cleaned data would be saved to 
# and manipulated for future operations
targetTable = "AppendTest"

# Inspect target table
list_tableContents(targetTable)
# Out:
# AppendTest Contents
# Table Values
# ---START---
# ---END---

# %%
# Function to list contents in target table
def list_tableColDtype(targetTable):
    cursor.execute(f"SELECT COLUMN_NAME, DATA_TYPE FROM information_schema.columns where TABLE_NAME = '{targetTable}'")
    results = cursor.fetchall()
    print(targetTable, "Contents")
    counter = 0
    print("Table Column Data Type")
    print("---START---")
    for row in results:
        counter=counter+1
        print(counter, row)
    print("---END---")

# Inspect target table
targetTable = "AppendTest"
list_tableColDtype(targetTable)
# Out:
# AppendTest Contents
# Table Column Data Type
# ---START---
# 1 ('eventID', 'int')
# 2 ('DATEANDTIME', 'datetime')
# 3 ('eventDesc', 'text')
# 4 ('TnF', 'int')
# 5 ('blanCol', 'int')
# 6 ('DATETIME_LOADED', 'datetime')
# ---END---

# %%
# Function to Create a dataframe with dummy data for testing purposes
def createDummyDataDF(inputData = "A"):
    if (inputData == "A"):
        dummyData = {
                     'eventID': [1, 2, 3],
                     'DATEANDTIME': [1644223829, 1644310229, 1644396629],
                     'eventDesc': ['Alpha', 'Bravo', 'Charlie'],
                     'TnF': [1, 1, 1] 
                    }
    else:
        dummyData = {
                     'eventID': [4, 5, 6],
                     'DATEANDTIME': [1644223829, 1644310229, 1644396629],
                     'eventDesc': ['Delta', 'Echo', 'Foxtrot'],
                     'TnF': [0, 0, 0] 
                    }
    
    df = pd.DataFrame(dummyData)
    df['DATEANDTIME'] = pd.to_datetime(df['DATEANDTIME'], unit='s')

    # To get time in seconds resolution if it comes in higher resolutions
    # Not required
    #df['TIME_S'] = df['DATEANDTIME'].dt.floor("s").dt.time

    return df

# Generate test dataframe in testing mode
if (testMode == True):
    # Create a dummy dataframe for testing purposes
    testDF = createDummyDataDF()
    print("Dataframe columns would have the same data type as SQL table values")
    testDF.info()
else:
    print("Test script skipped")
# Out:
# Dataframe columns would have the same data type as SQL table values
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   eventID      3 non-null      int64
#  1   DATEANDTIME  3 non-null      datetime64[ns]
#  2   eventDesc    3 non-null      object
#  3   TnF          3 non-null      int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
# Inspect test dataframe
if (testMode == True):
    # Inspect Data
    print(testDF.head())
else:
    print("Test script skipped")
# Out:
#    eventID         DATEANDTIME eventDesc  TnF
# 0        1 2022-02-07 08:50:29     Alpha    1
# 1        2 2022-02-08 08:50:29     Bravo    1
# 2        3 2022-02-09 08:50:29   Charlie    1

# %%
# Function to append data to database as an entire dataframe
def appendData(tableName, inputDF, serverParams):    
    # Create connection engine 
    # Default connection function only works for SQLite
    engine = sqlalchemy.create_engine("mssql+pyodbc:///?odbc_connect={}".format(serverParams))
    # Append data
    inputDF.to_sql(tableName, con=engine, if_exists="append", index = False)

# %%
# Test data append function
if (testMode == True):
    # Test if append dataframe function works
    appendData("AppendTest", testDF, serverParams)
    list_tableContents("AppendTest")
else:
    print("Test script skipped")
# Out:
# AppendTest Contents
# Table Values
# ---START---
# 1 (1, datetime.datetime(2022, 2, 7, 8, 50, 29), 'Alpha', 1, None, datetime.datetime(2022, 4, 7, 11, 11, 33, 297000))
# 2 (2, datetime.datetime(2022, 2, 8, 8, 50, 29), 'Bravo', 1, None, datetime.datetime(2022, 4, 7, 11, 11, 33, 297000))
# 3 (3, datetime.datetime(2022, 2, 9, 8, 50, 29), 'Charlie', 1, None, datetime.datetime(2022, 4, 7, 11, 11, 33, 297000))
# ---END---

# %%
# Function to delete last n rows in table sorted by datetime (oldest first)
def delDataNRow(targetTable, nRow=3):
    cursor.execute(f"WITH CTE AS (SELECT TOP {nRow} * FROM {targetTable} ORDER BY DATEANDTIME DESC) DELETE FROM CTE")
    conn.commit()
    
# Function to delete all rows in table
def delDataAll(targetTable):
    cursor.execute(f"DELETE FROM {targetTable}")
    conn.commit()

# %%
# Test data delete latest nRows function
if (testMode == True):
    delDataNRow(targetTable, nRow=2)
    list_tableContents(targetTable)
else:
    print("Test script skipped")
# Out:
# AppendTest Contents
# Table Values
# ---START---
# 1 (1, datetime.datetime(2022, 2, 7, 8, 50, 29), 'Alpha', 1, None, datetime.datetime(2022, 4, 7, 11, 11, 33, 297000))
# ---END---

# %%
# Test data delete all function
if (resetTableData == True):
    delDataAll(targetTable)
    list_tableContents(targetTable)
else:
    print("Test script skipped")
# Out:
# AppendTest Contents
# Table Values
# ---START---
# ---END---

# %%
# Delete redundant variables used in test
if (resetTableData == True):
    del testDF
else:
    print("Test script skipped")

# %% [markdown]
# ## Push Raw Logs to SQL Server

# %%
# Define function to transfer files which has been processed successfully to an archive folder
def fileTransfer(file_name, dst_folder, src_folder=""):
    # If current folder is the source directory for the files, leave src_folder empty
    # check if file exist in destination
    if os.path.exists(dst_folder + file_name):
        # Split name and file type extension
        data = os.path.splitext(file_name)
        only_name = data[0]
        extension = data[1]
        # Adding the new name
        new_base = only_name + '_new' + extension
        # construct full file path
        new_name = os.path.join(dst_folder, new_base)
        # move file
        shutil.move(src_folder + file_name, new_name)
    else:
        shutil.move(src_folder + file_name, dst_folder + file_name)
    print(file_name, "Transferred to destination folder", dst_folder)

# %%
# Get timestamp of operation start:
dateTimeStartOp = dt.datetime.now()
print("Start Operation")
print(dateTimeStartOp)

# Get list of files to initialise
fileList = os.listdir()
# Ignore temp files (large files not fully downloaded)
fileList = [filteredList for filteredList in fileList if "~$" not in filteredList]
fileList = [filteredList for filteredList in fileList if ".temp" not in filteredList]
fileList = [filteredList for filteredList in fileList if ".tmp" not in filteredList]

# Define Archive Folder Location and Target table
if (prefix == 'TestAE'):
    targetTable = "eventList"
    archiveFolderLoc = "../EventLogs_archive/"
else:
    targetTable = "alarmList"
    archiveFolderLoc = "../AlarmLogs_archive/"
    
# Define wait time for new files to be added
# If there are no more files within directory
# Else the script will be terminated
# Time is in seconds
waitTimeInterval = 1
waitTimeLimit = 10

while (len(fileList) > 0):
    # Initiate batch run  
    print("Start batch run")
    # Get timestamp of batch run start:
    dateTimeStartBatch = dt.datetime.now()
    print(dateTimeStartBatch)
    
    for file in fileList:
        # Get Oldest File in Directory in a First in First Out (FIFO) manner as an input
        inputFile = min(fileList, key=os.path.getctime)
        
        #############################################
        # Process file as a cleaned dataframe - START
        #############################################
        
        # Get timestamp of run start:
        print("Commence processing of", inputFile)
        dateTimeStartRun = dt.datetime.now()
        print(dateTimeStartRun)
        
        # Ingest log files as a dataframe for further processing
        df = cleaningScript_vector(inputFile, prefix, True)
        
        #############################################
        # Process file as a cleaned dataframe - END
        #############################################
        
        # Append data to SQL DB
        appendData(targetTable, df, serverParams)

        # Archive processed file
        fileTransfer(inputFile, archiveFolderLoc)
        #print(inputFile, "archived")
        
        # Update list of files
        fileList = os.listdir()
        # Ignore temp files (large files not fully downloaded)
        fileList = [filteredList for filteredList in fileList if "~$" not in filteredList]
        fileList = [filteredList for filteredList in fileList if ".temp" not in filteredList]
        fileList = [filteredList for filteredList in fileList if ".tmp" not in filteredList]
        
        # Get timestamp of run end: 
        dateTimeEndRun = dt.datetime.now()
        print("Run Tlapsed Time")
        print(dateTimeEndRun - dateTimeStartRun)
        del dateTimeEndRun, dateTimeStartRun
        
    print("Batch run completed")
    # Get timestamp of batch run end:
    dateTimeEndBatch = dt.datetime.now()
    print(dateTimeEndBatch)
    print("Batch Elapsed Time")
    print(dateTimeEndBatch - dateTimeStartBatch)
    del dateTimeEndBatch, dateTimeStartBatch
    
    # Check if new files are added to restart process
    timeCounter = 0
    while (len(fileList) == 0):
        # When initial batch run is completed check again for newly added files
        # This is to account for any lag or latency in the file transfer
        # n second(s) timer delay between batches
        time.sleep(waitTimeInterval)
        timeCounter = timeCounter + waitTimeInterval
        
        # Update list of files
        fileList = os.listdir()
        # Ignore temp files (large files not fully downloaded)
        fileList = [filteredList for filteredList in fileList if "~$" not in filteredList]
        fileList = [filteredList for filteredList in fileList if ".temp" not in filteredList]
        fileList = [filteredList for filteredList in fileList if ".tmp" not in filteredList]

        # Terminate script if wait too long
        if (timeCounter > waitTimeLimit):
            break
        
    
print("Script Terminated")
dateTimeEndOp = dt.datetime.now()
print(dateTimeEndOp)
print("Operation Elapsed Time")
print(dateTimeEndOp - dateTimeStartOp)
# Out:
# Start Operation
# 2022-04-07 11:11:33.410376
# Start batch run
# 2022-04-07 11:11:33.413377
# Commence processing of AlarmListTest_1638320410_254559
# 2022-04-07 11:11:33.445376
# 0
# 0
# AlarmListTest_1638320410_254559 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.074000
# Commence processing of AlarmListTest_1638320436_251896
# 2022-04-07 11:11:33.551376
# 0
# 0
# AlarmListTest_1638320436_251896 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.151723
# Commence processing of AlarmListTest_1638320437_252131
# 2022-04-07 11:11:37.740101
# 0
# 0
# AlarmListTest_1638320437_252131 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.117000
# Commence processing of AlarmListTest_1638320443_251730
# 2022-04-07 11:11:37.890129
# 0
# 0
# AlarmListTest_1638320443_251730 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.078972
# Commence processing of AlarmListTest_1638320444_252726
# 2022-04-07 11:11:38.003101
# 0
# 0
# AlarmListTest_1638320444_252726 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.182185
# Commence processing of AlarmListTest_1638320449_252618
# 2022-04-07 11:11:42.218288
# 0
# 0
# AlarmListTest_1638320449_252618 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.089996
# Commence processing of AlarmListTest_1638320450_252605
# 2022-04-07 11:11:42.346286
# 0
# 0
# AlarmListTest_1638320450_252605 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.172453
# Commence processing of AlarmListTest_1638320451_253568
# 2022-04-07 11:11:46.550776
# 0
# 0
# AlarmListTest_1638320451_253568 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.039996
# Commence processing of AlarmListTest_1638320452_252506
# 2022-04-07 11:11:46.622740
# 0
# 0
# AlarmListTest_1638320452_252506 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.168318
# Commence processing of AlarmListTest_1638320453_252487
# 2022-04-07 11:11:50.823057
# 0
# 0
# AlarmListTest_1638320453_252487 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070000
# Commence processing of AlarmListTest_1638320456_252088
# 2022-04-07 11:11:50.925057
# 0
# 0
# AlarmListTest_1638320456_252088 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.169510
# Commence processing of AlarmListTest_1638320457_252068
# 2022-04-07 11:11:55.125567
# 0
# 0
# AlarmListTest_1638320457_252068 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.064999
# Commence processing of AlarmListTest_1638320458_252124
# 2022-04-07 11:11:55.223566
# 0
# 0
# AlarmListTest_1638320458_252124 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.067001
# Commence processing of AlarmListTest_1638320459_251455
# 2022-04-07 11:11:55.324566
# 0
# 0
# AlarmListTest_1638320459_251455 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069008
# Commence processing of AlarmListTest_1638320461_251451
# 2022-04-07 11:11:55.426567
# 0
# 0
# AlarmListTest_1638320461_251451 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.050001
# Commence processing of AlarmListTest_1638320467_252287
# 2022-04-07 11:11:55.509566
# 0
# 0
# AlarmListTest_1638320467_252287 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.149741
# Commence processing of AlarmListTest_1638320468_252600
# 2022-04-07 11:11:59.689340
# 0
# 0
# AlarmListTest_1638320468_252600 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.125125
# Commence processing of AlarmListTest_1638320498_251655
# 2022-04-07 11:12:03.844499
# 0
# 0
# AlarmListTest_1638320498_251655 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.065999
# Commence processing of AlarmListTest_1638320510_252410
# 2022-04-07 11:12:03.940498
# 0
# 0
# AlarmListTest_1638320510_252410 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.075967
# Commence processing of AlarmListTest_1638320511_253513
# 2022-04-07 11:12:04.046466
# 0
# 0
# AlarmListTest_1638320511_253513 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.063025
# Commence processing of AlarmListTest_1638320520_254237
# 2022-04-07 11:12:04.139468
# 0
# 0
# AlarmListTest_1638320520_254237 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.081997
# Commence processing of AlarmListTest_1638320526_252175
# 2022-04-07 11:12:04.255466
# 0
# 0
# AlarmListTest_1638320526_252175 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.063999
# Commence processing of AlarmListTest_1638320531_253175
# 2022-04-07 11:12:04.350497
# 0
# 0
# AlarmListTest_1638320531_253175 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.046967
# Commence processing of AlarmListTest_1638320539_251840
# 2022-04-07 11:12:04.427476
# 0
# 0
# AlarmListTest_1638320539_251840 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.045988
# Commence processing of AlarmListTest_1638320560_251484
# 2022-04-07 11:12:04.504467
# 0
# 0
# AlarmListTest_1638320560_251484 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.063998
# Commence processing of AlarmListTest_1638320564_251361
# 2022-04-07 11:12:04.598501
# 0
# 0
# AlarmListTest_1638320564_251361 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062963
# Commence processing of AlarmListTest_1638320571_253344
# 2022-04-07 11:12:04.691464
# 0
# 0
# AlarmListTest_1638320571_253344 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062035
# Commence processing of AlarmListTest_1638320583_254020
# 2022-04-07 11:12:04.783499
# 0
# 0
# AlarmListTest_1638320583_254020 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.072966
# Commence processing of AlarmListTest_1638320584_251994
# 2022-04-07 11:12:04.885497
# 0
# 0
# AlarmListTest_1638320584_251994 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060970
# Commence processing of AlarmListTest_1638320585_251975
# 2022-04-07 11:12:04.980463
# 0
# 0
# AlarmListTest_1638320585_251975 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.065003
# Commence processing of AlarmListTest_1638320587_251963
# 2022-04-07 11:12:05.076497
# 0
# 0
# AlarmListTest_1638320587_251963 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.075969
# Commence processing of AlarmListTest_1638320588_253905
# 2022-04-07 11:12:05.187463
# 0
# 0
# AlarmListTest_1638320588_253905 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.087001
# Commence processing of AlarmListTest_1638320591_254110
# 2022-04-07 11:12:05.309464
# 0
# 0
# AlarmListTest_1638320591_254110 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.083001
# Commence processing of AlarmListTest_1638320592_252884
# 2022-04-07 11:12:05.425465
# 0
# 0
# AlarmListTest_1638320592_252884 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079999
# Commence processing of AlarmListTest_1638320594_252759
# 2022-04-07 11:12:05.536465
# 0
# 0
# AlarmListTest_1638320594_252759 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.095000
# Commence processing of AlarmListTest_1638320595_253494
# 2022-04-07 11:12:05.665495
# 0
# 0
# AlarmListTest_1638320595_253494 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.073970
# Commence processing of AlarmListTest_1638320598_251732
# 2022-04-07 11:12:05.772464
# 0
# 0
# AlarmListTest_1638320598_251732 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079000
# Commence processing of AlarmListTest_1638320601_251773
# 2022-04-07 11:12:05.890464
# 0
# 0
# AlarmListTest_1638320601_251773 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.092030
# Commence processing of AlarmListTest_1638320602_251735
# 2022-04-07 11:12:06.016478
# 0
# 0
# AlarmListTest_1638320602_251735 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.089986
# Commence processing of AlarmListTest_1638320608_251982
# 2022-04-07 11:12:06.138465
# 0
# 0
# AlarmListTest_1638320608_251982 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.072000
# Commence processing of AlarmListTest_1638320616_252463
# 2022-04-07 11:12:06.243464
# 0
# 0
# AlarmListTest_1638320616_252463 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.085000
# Commence processing of AlarmListTest_1638320617_252678
# 2022-04-07 11:12:06.361464
# 0
# 0
# AlarmListTest_1638320617_252678 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.086001
# Commence processing of AlarmListTest_1638320619_252364
# 2022-04-07 11:12:06.484465
# 0
# 0
# AlarmListTest_1638320619_252364 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.111000
# Commence processing of AlarmListTest_1638320621_254256
# 2022-04-07 11:12:06.634464
# 0
# 0
# AlarmListTest_1638320621_254256 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.052001
# Commence processing of AlarmListTest_1638320629_254212
# 2022-04-07 11:12:06.717464
# 0
# 0
# AlarmListTest_1638320629_254212 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080000
# Commence processing of AlarmListTest_1638320630_254200
# 2022-04-07 11:12:06.830464
# 0
# 0
# AlarmListTest_1638320630_254200 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.086001
# Commence processing of AlarmListTest_1638320631_255337
# 2022-04-07 11:12:06.950495
# 0
# 0
# AlarmListTest_1638320631_255337 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.076971
# Commence processing of AlarmListTest_1638320634_252144
# 2022-04-07 11:12:07.059465
# 0
# 0
# AlarmListTest_1638320634_252144 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.086001
# Commence processing of AlarmListTest_1638320635_252424
# 2022-04-07 11:12:07.178468
# 0
# 0
# AlarmListTest_1638320635_252424 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.042520
# Commence processing of AlarmListTest_1638320640_252905
# 2022-04-07 11:12:07.255529
# 0
# 0
# AlarmListTest_1638320640_252905 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.092999
# Commence processing of AlarmListTest_1638320641_252018
# 2022-04-07 11:12:07.383528
# 0
# 0
# AlarmListTest_1638320641_252018 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.089000
# Commence processing of AlarmListTest_1638320647_251786
# 2022-04-07 11:12:07.506529
# 0
# 0
# AlarmListTest_1638320647_251786 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.090029
# Commence processing of AlarmListTest_1638320648_251756
# 2022-04-07 11:12:07.629530
# 0
# 0
# AlarmListTest_1638320648_251756 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.096033
# Commence processing of AlarmListTest_1638320649_251708
# 2022-04-07 11:12:07.758528
# 0
# 0
# AlarmListTest_1638320649_251708 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.096029
# Commence processing of AlarmListTest_1638320650_251692
# 2022-04-07 11:12:07.887529
# 0
# 0
# AlarmListTest_1638320650_251692 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.083998
# Commence processing of AlarmListTest_1638320656_252660
# 2022-04-07 11:12:08.004527
# 0
# 0
# AlarmListTest_1638320656_252660 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.084004
# Commence processing of AlarmListTest_1638320657_252640
# 2022-04-07 11:12:08.121527
# 0
# 0
# AlarmListTest_1638320657_252640 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.084001
# Commence processing of AlarmListTest_1638320663_251398
# 2022-04-07 11:12:08.234572
# 0
# 0
# AlarmListTest_1638320663_251398 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080957
# Commence processing of AlarmListTest_1638320677_252121
# 2022-04-07 11:12:08.346528
# 0
# 0
# AlarmListTest_1638320677_252121 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.083042
# Commence processing of AlarmListTest_1638320684_254072
# 2022-04-07 11:12:08.462528
# 0
# 0
# AlarmListTest_1638320684_254072 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.091000
# Commence processing of AlarmListTest_1638320685_254137
# 2022-04-07 11:12:08.583528
# 0
# 0
# AlarmListTest_1638320685_254137 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.096000
# Commence processing of AlarmListTest_1638320687_254106
# 2022-04-07 11:12:08.708528
# 0
# 0
# AlarmListTest_1638320687_254106 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.076000
# Commence processing of AlarmListTest_1638320693_251942
# 2022-04-07 11:12:08.814527
# 0
# 0
# AlarmListTest_1638320693_251942 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.051002
# Commence processing of AlarmListTest_1638320695_251898
# 2022-04-07 11:12:08.896527
# 0
# 0
# AlarmListTest_1638320695_251898 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.071001
# Commence processing of AlarmListTest_1638320696_251933
# 2022-04-07 11:12:08.997529
# 0
# 0
# AlarmListTest_1638320696_251933 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.081000
# Commence processing of AlarmListTest_1638320705_251660
# 2022-04-07 11:12:09.109530
# 0
# 0
# AlarmListTest_1638320705_251660 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.081033
# Commence processing of AlarmListTest_1638320710_251621
# 2022-04-07 11:12:09.220565
# 0
# 0
# AlarmListTest_1638320710_251621 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.098280
# Commence processing of AlarmListTest_1638320711_252800
# 2022-04-07 11:12:09.349843
# 0
# 0
# AlarmListTest_1638320711_252800 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.081033
# Commence processing of AlarmListTest_1638320712_251590
# 2022-04-07 11:12:09.460876
# 0
# 0
# AlarmListTest_1638320712_251590 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.076967
# Commence processing of AlarmListTest_1638320713_251599
# 2022-04-07 11:12:09.567842
# 0
# 0
# AlarmListTest_1638320713_251599 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.093000
# Commence processing of AlarmListTest_1638320721_252437
# 2022-04-07 11:12:09.692842
# 0
# 0
# AlarmListTest_1638320721_252437 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.095001
# Commence processing of AlarmListTest_1638320722_252408
# 2022-04-07 11:12:09.818843
# 0
# 0
# AlarmListTest_1638320722_252408 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.084999
# Commence processing of AlarmListTest_1638320731_255269
# 2022-04-07 11:12:09.933879
# 0
# 0
# AlarmListTest_1638320731_255269 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069965
# Commence processing of AlarmListTest_1638320732_254127
# 2022-04-07 11:12:10.035846
# 0
# 0
# AlarmListTest_1638320732_254127 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.092998
# Commence processing of AlarmListTest_1638320736_254097
# 2022-04-07 11:12:10.159844
# 0
# 0
# AlarmListTest_1638320736_254097 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.074000
# Commence processing of AlarmListTest_1638320737_254150
# 2022-04-07 11:12:10.266846
# 0
# 0
# AlarmListTest_1638320737_254150 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.086999
# Commence processing of AlarmListTest_1638320738_252361
# 2022-04-07 11:12:10.382845
# 0
# 0
# AlarmListTest_1638320738_252361 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.087998
# Commence processing of AlarmListTest_1638320739_252130
# 2022-04-07 11:12:10.502843
# 0
# 0
# AlarmListTest_1638320739_252130 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.087001
# Commence processing of AlarmListTest_1638320744_252920
# 2022-04-07 11:12:10.619845
# 0
# 0
# AlarmListTest_1638320744_252920 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080999
# Commence processing of AlarmListTest_1638320752_252153
# 2022-04-07 11:12:10.728875
# 0
# 0
# AlarmListTest_1638320752_252153 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.064000
# Commence processing of AlarmListTest_1638320755_251697
# 2022-04-07 11:12:10.823844
# 0
# 0
# AlarmListTest_1638320755_251697 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.038032
# Commence processing of AlarmListTest_1638320758_252605
# 2022-04-07 11:12:10.888875
# 0
# 0
# AlarmListTest_1638320758_252605 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.063003
# Commence processing of AlarmListTest_1638320759_252527
# 2022-04-07 11:12:10.979876
# 0
# 0
# AlarmListTest_1638320759_252527 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062999
# Commence processing of AlarmListTest_1638320760_252540
# 2022-04-07 11:12:11.069875
# 0
# 0
# AlarmListTest_1638320760_252540 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.072970
# Commence processing of AlarmListTest_1638320768_251494
# 2022-04-07 11:12:11.173845
# 0
# 0
# AlarmListTest_1638320768_251494 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069001
# Commence processing of AlarmListTest_1638320769_251418
# 2022-04-07 11:12:11.272842
# 0
# 0
# AlarmListTest_1638320769_251418 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.066001
# Commence processing of AlarmListTest_1638320771_255457
# 2022-04-07 11:12:11.366875
# 0
# 0
# AlarmListTest_1638320771_255457 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.035003
# Commence processing of AlarmListTest_1638320775_254315
# 2022-04-07 11:12:11.433875
# 0
# 0
# AlarmListTest_1638320775_254315 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.072968
# Commence processing of AlarmListTest_1638320779_252485
# 2022-04-07 11:12:11.537845
# 0
# 0
# AlarmListTest_1638320779_252485 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079000
# Commence processing of AlarmListTest_1638320787_253968
# 2022-04-07 11:12:11.645842
# 0
# 0
# AlarmListTest_1638320787_253968 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069003
# Commence processing of AlarmListTest_1638320788_252462
# 2022-04-07 11:12:11.745844
# 0
# 0
# AlarmListTest_1638320788_252462 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.077001
# Commence processing of AlarmListTest_1638320817_251527
# 2022-04-07 11:12:11.858845
# 0
# 0
# AlarmListTest_1638320817_251527 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069001
# Commence processing of AlarmListTest_1638320818_251616
# 2022-04-07 11:12:11.956842
# 0
# 0
# AlarmListTest_1638320818_251616 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070003
# Commence processing of AlarmListTest_1638320832_254108
# 2022-04-07 11:12:12.056841
# 0
# 0
# AlarmListTest_1638320832_254108 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070003
# Commence processing of AlarmListTest_1638320834_254166
# 2022-04-07 11:12:12.155843
# 0
# 0
# AlarmListTest_1638320834_254166 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.067000
# Commence processing of AlarmListTest_1638320843_252923
# 2022-04-07 11:12:12.251841
# 0
# 0
# AlarmListTest_1638320843_252923 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.075004
# Commence processing of AlarmListTest_1638320844_252900
# 2022-04-07 11:12:12.356842
# 0
# 0
# AlarmListTest_1638320844_252900 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070002
# Commence processing of AlarmListTest_1638320846_252978
# 2022-04-07 11:12:12.458843
# 0
# 0
# AlarmListTest_1638320846_252978 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.068000
# Commence processing of AlarmListTest_1638320847_252936
# 2022-04-07 11:12:12.557842
# 0
# 0
# AlarmListTest_1638320847_252936 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069001
# Commence processing of AlarmListTest_1638320862_251620
# 2022-04-07 11:12:12.656845
# 0
# 0
# AlarmListTest_1638320862_251620 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.035999
# Commence processing of AlarmListTest_1638320864_252509
# 2022-04-07 11:12:12.724844
# 0
# 0
# AlarmListTest_1638320864_252509 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.068031
# Commence processing of AlarmListTest_1638320867_252484
# 2022-04-07 11:12:12.822841
# 0
# 0
# AlarmListTest_1638320867_252484 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.047004
# Commence processing of AlarmListTest_1638320868_252476
# 2022-04-07 11:12:12.897845
# 0
# 0
# AlarmListTest_1638320868_252476 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069000
# Commence processing of AlarmListTest_1638320869_252778
# 2022-04-07 11:12:12.993843
# 0
# 0
# AlarmListTest_1638320869_252778 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.066002
# Commence processing of AlarmListTest_1638320870_252475
# 2022-04-07 11:12:13.090843
# 0
# 0
# AlarmListTest_1638320870_252475 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.081004
# Commence processing of AlarmListTest_1638320874_254349
# 2022-04-07 11:12:13.201846
# 0
# 0
# AlarmListTest_1638320874_254349 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069997
# Commence processing of AlarmListTest_1638320875_254343
# 2022-04-07 11:12:13.305842
# 0
# 0
# AlarmListTest_1638320875_254343 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079001
# Commence processing of AlarmListTest_1638320897_251905
# 2022-04-07 11:12:13.413844
# 0
# 0
# AlarmListTest_1638320897_251905 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069003
# Commence processing of AlarmListTest_1638320902_251858
# 2022-04-07 11:12:13.516841
# 0
# 0
# AlarmListTest_1638320902_251858 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.097034
# Commence processing of AlarmListTest_1638320903_251816
# 2022-04-07 11:12:13.644842
# 0
# 0
# AlarmListTest_1638320903_251816 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079001
# Commence processing of AlarmListTest_1638320904_252767
# 2022-04-07 11:12:13.751841
# 0
# 0
# AlarmListTest_1638320904_252767 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.074004
# Commence processing of AlarmListTest_1638320913_252577
# 2022-04-07 11:12:13.855842
# 0
# 0
# AlarmListTest_1638320913_252577 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062001
# Commence processing of AlarmListTest_1638320914_253128
# 2022-04-07 11:12:13.946844
# 0
# 0
# AlarmListTest_1638320914_253128 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.073004
# Commence processing of AlarmListTest_1638320918_252672
# 2022-04-07 11:12:14.048879
# 0
# 0
# AlarmListTest_1638320918_252672 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.067964
# Commence processing of AlarmListTest_1638320919_252641
# 2022-04-07 11:12:14.146842
# 0
# 0
# AlarmListTest_1638320919_252641 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.065033
# Commence processing of AlarmListTest_1638320931_253360
# 2022-04-07 11:12:14.240846
# 0
# 0
# AlarmListTest_1638320931_253360 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080997
# Commence processing of AlarmListTest_1638320933_252194
# 2022-04-07 11:12:14.349842
# 0
# 0
# AlarmListTest_1638320933_252194 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.083001
# Commence processing of AlarmListTest_1638320934_252211
# 2022-04-07 11:12:14.462845
# 0
# 0
# AlarmListTest_1638320934_252211 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.068998
# Commence processing of AlarmListTest_1638320937_252200
# 2022-04-07 11:12:14.562843
# 0
# 0
# AlarmListTest_1638320937_252200 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.043002
# Commence processing of AlarmListTest_1638320939_254329
# 2022-04-07 11:12:14.634844
# 0
# 0
# AlarmListTest_1638320939_254329 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080002
# Commence processing of AlarmListTest_1638320941_255039
# 2022-04-07 11:12:14.745843
# 0
# 0
# AlarmListTest_1638320941_255039 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.067001
# Commence processing of AlarmListTest_1638320943_253996
# 2022-04-07 11:12:14.843841
# 0
# 0
# AlarmListTest_1638320943_253996 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.068004
# Commence processing of AlarmListTest_1638320949_252868
# 2022-04-07 11:12:14.940843
# 0
# 0
# AlarmListTest_1638320949_252868 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079017
# Commence processing of AlarmListTest_1638320955_252795
# 2022-04-07 11:12:15.048875
# 0
# 0
# AlarmListTest_1638320955_252795 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.068969
# Commence processing of AlarmListTest_1638320956_254024
# 2022-04-07 11:12:15.148845
# 0
# 0
# AlarmListTest_1638320956_254024 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079001
# Commence processing of AlarmListTest_1638320960_251688
# 2022-04-07 11:12:15.256846
# 0
# 0
# AlarmListTest_1638320960_251688 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.083999
# Commence processing of AlarmListTest_1638320961_251633
# 2022-04-07 11:12:15.370845
# 0
# 0
# AlarmListTest_1638320961_251633 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.074997
# Commence processing of AlarmListTest_1638320977_252637
# 2022-04-07 11:12:15.472841
# 0
# 0
# AlarmListTest_1638320977_252637 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069030
# Commence processing of AlarmListTest_1638320979_254249
# 2022-04-07 11:12:15.572841
# 0
# 0
# AlarmListTest_1638320979_254249 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.071004
# Commence processing of AlarmListTest_1638320983_254256
# 2022-04-07 11:12:15.672842
# 0
# 0
# AlarmListTest_1638320983_254256 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.112502
# Commence processing of AlarmListTest_1638320985_254242
# 2022-04-07 11:12:19.813377
# 0
# 0
# AlarmListTest_1638320985_254242 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.064950
# Commence processing of AlarmListTest_1638320986_254847
# 2022-04-07 11:12:19.903361
# 0
# 0
# AlarmListTest_1638320986_254847 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060968
# Commence processing of AlarmListTest_1638320989_254136
# 2022-04-07 11:12:19.990329
# 0
# 0
# AlarmListTest_1638320989_254136 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.065000
# Commence processing of AlarmListTest_1638320990_252203
# 2022-04-07 11:12:20.081329
# 0
# 0
# AlarmListTest_1638320990_252203 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060000
# Commence processing of AlarmListTest_1638320999_251921
# 2022-04-07 11:12:20.167360
# 0
# 0
# AlarmListTest_1638320999_251921 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062969
# Commence processing of AlarmListTest_1638321001_251869
# 2022-04-07 11:12:20.256360
# 0
# 0
# AlarmListTest_1638321001_251869 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062967
# Commence processing of AlarmListTest_1638321002_251844
# 2022-04-07 11:12:20.346362
# 0
# 0
# AlarmListTest_1638321002_251844 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.044000
# Commence processing of AlarmListTest_1638321003_252018
# 2022-04-07 11:12:20.415364
# 0
# 0
# AlarmListTest_1638321003_252018 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.072998
# Commence processing of AlarmListTest_1638321019_252620
# 2022-04-07 11:12:20.513359
# 0
# 0
# AlarmListTest_1638321019_252620 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.064997
# Commence processing of AlarmListTest_1638321022_251941
# 2022-04-07 11:12:20.605364
# 0
# 0
# AlarmListTest_1638321022_251941 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061997
# Commence processing of AlarmListTest_1638321023_251458
# 2022-04-07 11:12:20.693361
# 0
# 0
# AlarmListTest_1638321023_251458 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.059966
# Commence processing of AlarmListTest_1638321024_251469
# 2022-04-07 11:12:20.778326
# 0
# 0
# AlarmListTest_1638321024_251469 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062002
# Commence processing of AlarmListTest_1638321044_254059
# 2022-04-07 11:12:20.864327
# 0
# 0
# AlarmListTest_1638321044_254059 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060000
# Commence processing of AlarmListTest_1638321047_254021
# 2022-04-07 11:12:20.950328
# 0
# 0
# AlarmListTest_1638321047_254021 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.059999
# Commence processing of AlarmListTest_1638321048_253965
# 2022-04-07 11:12:21.034326
# 0
# 0
# AlarmListTest_1638321048_253965 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060011
# Commence processing of AlarmListTest_1638321049_254309
# 2022-04-07 11:12:21.120360
# 0
# 0
# AlarmListTest_1638321049_254309 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.065971
# Commence processing of AlarmListTest_1638321050_252010
# 2022-04-07 11:12:21.210358
# 0
# 0
# AlarmListTest_1638321050_252010 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060969
# Commence processing of AlarmListTest_1638321060_252760
# 2022-04-07 11:12:21.296365
# 0
# 0
# AlarmListTest_1638321060_252760 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.063962
# Commence processing of AlarmListTest_1638321061_252763
# 2022-04-07 11:12:21.386329
# 0
# 0
# AlarmListTest_1638321061_252763 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061032
# Commence processing of AlarmListTest_1638321066_251635
# 2022-04-07 11:12:21.471361
# 0
# 0
# AlarmListTest_1638321066_251635 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062001
# Commence processing of AlarmListTest_1638321074_251475
# 2022-04-07 11:12:21.558363
# 0
# 0
# AlarmListTest_1638321074_251475 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.073964
# Commence processing of AlarmListTest_1638321075_252479
# 2022-04-07 11:12:21.657361
# 0
# 0
# AlarmListTest_1638321075_252479 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061968
# Commence processing of AlarmListTest_1638321076_278810
# 2022-04-07 11:12:21.743360
# 0
# 0
# AlarmListTest_1638321076_278810 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.046986
# Commence processing of AlarmListTest_1638321085_255316
# 2022-04-07 11:12:21.817330
# 0
# 0
# AlarmListTest_1638321085_255316 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.036997
# Commence processing of AlarmListTest_1638321086_254287
# 2022-04-07 11:12:21.879329
# 0
# 0
# AlarmListTest_1638321086_254287 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.158549
# Commence processing of AlarmListTest_1638321087_254269
# 2022-04-07 11:12:26.061911
# 0
# 0
# AlarmListTest_1638321087_254269 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062700
# Commence processing of AlarmListTest_1638321099_252034
# 2022-04-07 11:12:26.148643
# 0
# 0
# AlarmListTest_1638321099_252034 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062968
# Commence processing of AlarmListTest_1638321109_251845
# 2022-04-07 11:12:26.235644
# 0
# 0
# AlarmListTest_1638321109_251845 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060970
# Commence processing of AlarmListTest_1638321110_251813
# 2022-04-07 11:12:26.320644
# 0
# 0
# AlarmListTest_1638321110_251813 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061969
# Commence processing of AlarmListTest_1638321126_252582
# 2022-04-07 11:12:26.407642
# 0
# 0
# AlarmListTest_1638321126_252582 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.086972
# Commence processing of AlarmListTest_1638321127_251528
# 2022-04-07 11:12:26.519660
# 0
# 0
# AlarmListTest_1638321127_251528 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.071984
# Commence processing of AlarmListTest_1638321135_254415
# 2022-04-07 11:12:26.616644
# 0
# 0
# AlarmListTest_1638321135_254415 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070970
# Commence processing of AlarmListTest_1638321136_254318
# 2022-04-07 11:12:26.712641
# 0
# 0
# AlarmListTest_1638321136_254318 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060970
# Commence processing of AlarmListTest_1638321137_254332
# 2022-04-07 11:12:26.798646
# 0
# 0
# AlarmListTest_1638321137_254332 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060965
# Commence processing of AlarmListTest_1638321140_252193
# 2022-04-07 11:12:26.883610
# 0
# 0
# AlarmListTest_1638321140_252193 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061001
# Commence processing of AlarmListTest_1638321141_252114
# 2022-04-07 11:12:26.976613
# 0
# 0
# AlarmListTest_1638321141_252114 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060997
# Commence processing of AlarmListTest_1638321150_251965
# 2022-04-07 11:12:27.061610
# 0
# 0
# AlarmListTest_1638321150_251965 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061004
# Commence processing of AlarmListTest_1638321153_251934
# 2022-04-07 11:12:27.146647
# 0
# 0
# AlarmListTest_1638321153_251934 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.071968
# Commence processing of AlarmListTest_1638321154_251921
# 2022-04-07 11:12:27.242647
# 0
# 0
# AlarmListTest_1638321154_251921 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062967
# Commence processing of AlarmListTest_1638321157_252102
# 2022-04-07 11:12:27.329644
# 0
# 0
# AlarmListTest_1638321157_252102 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.045967
# Commence processing of AlarmListTest_1638321169_251627
# 2022-04-07 11:12:27.399611
# 0
# 0
# AlarmListTest_1638321169_251627 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.076000
# Commence processing of AlarmListTest_1638321180_252466
# 2022-04-07 11:12:27.501644
# 0
# 0
# AlarmListTest_1638321180_252466 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.076970
# Commence processing of AlarmListTest_1638321181_252406
# 2022-04-07 11:12:27.605611
# 0
# 0
# AlarmListTest_1638321181_252406 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.067032
# Commence processing of AlarmListTest_1638321182_252390
# 2022-04-07 11:12:27.698616
# 0
# 0
# AlarmListTest_1638321182_252390 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.077036
# Commence processing of AlarmListTest_1638321201_252057
# 2022-04-07 11:12:27.800644
# 0
# 0
# AlarmListTest_1638321201_252057 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062967
# Commence processing of AlarmListTest_1638321216_251778
# 2022-04-07 11:12:27.887645
# 0
# 0
# AlarmListTest_1638321216_251778 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.078969
# Commence processing of AlarmListTest_1638321221_251604
# 2022-04-07 11:12:27.991612
# 0
# 0
# AlarmListTest_1638321221_251604 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.035999
# Commence processing of AlarmListTest_1638321225_252481
# 2022-04-07 11:12:28.052612
# 0
# 0
# AlarmListTest_1638321225_252481 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.067000
# Commence processing of AlarmListTest_1638321227_254993
# 2022-04-07 11:12:28.145610
# 0
# 0
# AlarmListTest_1638321227_254993 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.068003
# Commence processing of AlarmListTest_1638321228_252545
# 2022-04-07 11:12:28.236644
# 0
# 0
# AlarmListTest_1638321228_252545 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.065972
# Commence processing of AlarmListTest_1638321229_252838
# 2022-04-07 11:12:28.326644
# 0
# 0
# AlarmListTest_1638321229_252838 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061966
# Commence processing of AlarmListTest_1638321231_253692
# 2022-04-07 11:12:28.414611
# 0
# 0
# AlarmListTest_1638321231_253692 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.063003
# Commence processing of AlarmListTest_1638321242_254222
# 2022-04-07 11:12:28.501641
# 0
# 0
# AlarmListTest_1638321242_254222 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.045014
# Commence processing of AlarmListTest_1638321245_253965
# 2022-04-07 11:12:28.570610
# 0
# 0
# AlarmListTest_1638321245_253965 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.065001
# Commence processing of AlarmListTest_1638321246_252120
# 2022-04-07 11:12:28.659645
# 0
# 0
# AlarmListTest_1638321246_252120 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070966
# Commence processing of AlarmListTest_1638321248_252116
# 2022-04-07 11:12:28.753644
# 0
# 0
# AlarmListTest_1638321248_252116 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.034001
# Commence processing of AlarmListTest_1638321249_252086
# 2022-04-07 11:12:28.811613
# 0
# 0
# AlarmListTest_1638321249_252086 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.059997
# Commence processing of AlarmListTest_1638321250_252044
# 2022-04-07 11:12:28.894611
# 0
# 0
# AlarmListTest_1638321250_252044 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.059000
# Commence processing of AlarmListTest_1638321260_251873
# 2022-04-07 11:12:28.977646
# 0
# 0
# AlarmListTest_1638321260_251873 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062967
# Commence processing of AlarmListTest_1638321274_251830
# 2022-04-07 11:12:29.062644
# 0
# 0
# AlarmListTest_1638321274_251830 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.074967
# Commence processing of AlarmListTest_1638321290_252249
# 2022-04-07 11:12:29.160644
# 0
# 0
# AlarmListTest_1638321290_252249 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062980
# Commence processing of AlarmListTest_1638321298_254029
# 2022-04-07 11:12:29.246611
# 0
# 0
# AlarmListTest_1638321298_254029 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061999
# Commence processing of AlarmListTest_1638321299_254078
# 2022-04-07 11:12:29.331645
# 0
# 0
# AlarmListTest_1638321299_254078 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.044966
# Commence processing of AlarmListTest_1638321301_254385
# 2022-04-07 11:12:29.399613
# 0
# 0
# AlarmListTest_1638321301_254385 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.064997
# Commence processing of AlarmListTest_1638321302_254068
# 2022-04-07 11:12:29.487644
# 0
# 0
# AlarmListTest_1638321302_254068 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060967
# Commence processing of AlarmListTest_1638321305_254018
# 2022-04-07 11:12:29.571645
# 0
# 0
# AlarmListTest_1638321305_254018 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061966
# Commence processing of AlarmListTest_1638321308_251878
# 2022-04-07 11:12:29.656614
# 0
# 0
# AlarmListTest_1638321308_251878 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.071996
# Commence processing of AlarmListTest_1638321313_252760
# 2022-04-07 11:12:29.751642
# 0
# 0
# AlarmListTest_1638321313_252760 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062969
# Commence processing of AlarmListTest_1638321317_251798
# 2022-04-07 11:12:29.839644
# 0
# 0
# AlarmListTest_1638321317_251798 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.044991
# Commence processing of AlarmListTest_1638321327_252540
# 2022-04-07 11:12:29.907614
# 0
# 0
# AlarmListTest_1638321327_252540 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.064997
# Commence processing of AlarmListTest_1638321328_252798
# 2022-04-07 11:12:29.996610
# 0
# 0
# AlarmListTest_1638321328_252798 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061037
# Commence processing of AlarmListTest_1638321329_252550
# 2022-04-07 11:12:30.079645
# 0
# 0
# AlarmListTest_1638321329_252550 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061965
# Commence processing of AlarmListTest_1638321332_252446
# 2022-04-07 11:12:30.165645
# 0
# 0
# AlarmListTest_1638321332_252446 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060968
# Commence processing of AlarmListTest_1638321333_252386
# 2022-04-07 11:12:30.248644
# 0
# 0
# AlarmListTest_1638321333_252386 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.063967
# Commence processing of AlarmListTest_1638321346_254565
# 2022-04-07 11:12:30.334647
# 0
# 0
# AlarmListTest_1638321346_254565 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060965
# Commence processing of AlarmListTest_1638321347_254099
# 2022-04-07 11:12:30.417644
# 0
# 0
# AlarmListTest_1638321347_254099 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.071970
# Commence processing of AlarmListTest_1638321349_252044
# 2022-04-07 11:12:30.517617
# 0
# 0
# AlarmListTest_1638321349_252044 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.068994
# Commence processing of AlarmListTest_1638321350_252095
# 2022-04-07 11:12:30.610610
# 0
# 0
# AlarmListTest_1638321350_252095 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080004
# Commence processing of AlarmListTest_1638321358_251961
# 2022-04-07 11:12:30.715647
# 0
# 0
# AlarmListTest_1638321358_251961 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080965
# Commence processing of AlarmListTest_1638321370_251822
# 2022-04-07 11:12:30.820611
# 0
# 0
# AlarmListTest_1638321370_251822 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062003
# Commence processing of AlarmListTest_1638321378_252534
# 2022-04-07 11:12:30.907611
# 0
# 0
# AlarmListTest_1638321378_252534 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070001
# Commence processing of AlarmListTest_1638321379_252426
# 2022-04-07 11:12:31.001613
# 0
# 0
# AlarmListTest_1638321379_252426 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.078000
# Commence processing of AlarmListTest_1638321384_251425
# 2022-04-07 11:12:31.107612
# 0
# 0
# AlarmListTest_1638321384_251425 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.071002
# Commence processing of AlarmListTest_1638321385_251391
# 2022-04-07 11:12:31.202639
# 0
# 0
# AlarmListTest_1638321385_251391 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.066974
# Commence processing of AlarmListTest_1638321386_254293
# 2022-04-07 11:12:31.294610
# 0
# 0
# AlarmListTest_1638321386_254293 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.078002
# Commence processing of AlarmListTest_1638321387_251364
# 2022-04-07 11:12:31.395612
# 0
# 0
# AlarmListTest_1638321387_251364 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062028
# Commence processing of AlarmListTest_1638321388_251345
# 2022-04-07 11:12:31.480644
# 0
# 0
# AlarmListTest_1638321388_251345 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.060004
# Commence processing of AlarmListTest_1638321389_254283
# 2022-04-07 11:12:31.562645
# 0
# 0
# AlarmListTest_1638321389_254283 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061001
# Commence processing of AlarmListTest_1638321390_254254
# 2022-04-07 11:12:31.645611
# 0
# 0
# AlarmListTest_1638321390_254254 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062035
# Commence processing of AlarmListTest_1638321403_254051
# 2022-04-07 11:12:31.728648
# 0
# 0
# AlarmListTest_1638321403_254051 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.034963
# Commence processing of AlarmListTest_1638321413_252854
# 2022-04-07 11:12:31.785652
# 0
# 0
# AlarmListTest_1638321413_252854 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.074988
# Commence processing of AlarmListTest_1638321417_256006
# 2022-04-07 11:12:31.882644
# 0
# 0
# AlarmListTest_1638321417_256006 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.048967
# Commence processing of AlarmListTest_1638321424_251684
# 2022-04-07 11:12:31.955614
# 0
# 0
# AlarmListTest_1638321424_251684 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061998
# Commence processing of AlarmListTest_1638321425_251745
# 2022-04-07 11:12:32.042639
# 0
# 0
# AlarmListTest_1638321425_251745 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.062972
# Commence processing of AlarmListTest_1638321426_251690
# 2022-04-07 11:12:32.127644
# 0
# 0
# AlarmListTest_1638321426_251690 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069967
# Commence processing of AlarmListTest_1638321427_252439
# 2022-04-07 11:12:32.219643
# 0
# 0
# AlarmListTest_1638321427_252439 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.089004
# Commence processing of AlarmListTest_1638321431_252745
# 2022-04-07 11:12:32.329648
# 0
# 0
# AlarmListTest_1638321431_252745 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.066963
# Commence processing of AlarmListTest_1638321432_251525
# 2022-04-07 11:12:32.422642
# 0
# 0
# AlarmListTest_1638321432_251525 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070971
# Commence processing of AlarmListTest_1638321454_252348
# 2022-04-07 11:12:32.518701
# 0
# 0
# AlarmListTest_1638321454_252348 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.073913
# Commence processing of AlarmListTest_1638321455_252039
# 2022-04-07 11:12:32.615612
# 0
# 0
# AlarmListTest_1638321455_252039 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.071002
# Commence processing of AlarmListTest_1638321456_252047
# 2022-04-07 11:12:32.711613
# 0
# 0
# AlarmListTest_1638321456_252047 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.065000
# Commence processing of AlarmListTest_1638321458_252912
# 2022-04-07 11:12:32.800613
# 0
# 0
# AlarmListTest_1638321458_252912 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.065005
# Commence processing of AlarmListTest_1638321459_252903
# 2022-04-07 11:12:32.888613
# 0
# 0
# ...
# 2022-04-07 11:13:22.792043
# 0
# 0
# AlarmListTest_1638323643_251425 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070001
# Commence processing of AlarmListTest_1638323646_252356
# 2022-04-07 11:13:22.866044
# 0
# 0
# AlarmListTest_1638323646_252356 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.067003
# Commence processing of AlarmListTest_1638323647_252321
# 2022-04-07 11:13:22.937046
# 0
# 0
# AlarmListTest_1638323647_252321 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080002
# Commence processing of AlarmListTest_1638323648_252267
# 2022-04-07 11:13:23.021047
# 0
# 0
# AlarmListTest_1638323648_252267 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.066999
# Commence processing of AlarmListTest_1638323649_252267
# 2022-04-07 11:13:23.091073
# 0
# 0
# AlarmListTest_1638323649_252267 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.145971
# Commence processing of AlarmListTest_1638323658_254228
# 2022-04-07 11:13:27.240064
# 0
# 0
# AlarmListTest_1638323658_254228 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.061979
# Commence processing of AlarmListTest_1638323662_254024
# 2022-04-07 11:13:27.305043
# 0
# 0
# AlarmListTest_1638323662_254024 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.178432
# Commence processing of AlarmListTest_1638323663_254023
# 2022-04-07 11:13:31.487505
# 0
# 0
# AlarmListTest_1638323663_254023 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.068969
# Commence processing of AlarmListTest_1638323668_253324
# 2022-04-07 11:13:31.560474
# 0
# 0
# AlarmListTest_1638323668_253324 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.149938
# Commence processing of AlarmListTest_1638323669_252994
# 2022-04-07 11:13:35.714409
# 0
# 0
# AlarmListTest_1638323669_252994 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079001
# Commence processing of AlarmListTest_1638323670_253057
# 2022-04-07 11:13:35.796410
# 0
# 0
# AlarmListTest_1638323670_253057 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.156999
# Commence processing of AlarmListTest_1638323674_251815
# 2022-04-07 11:13:39.956409
# 0
# 0
# AlarmListTest_1638323674_251815 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.160509
# Commence processing of AlarmListTest_1638323676_251787
# 2022-04-07 11:13:44.120918
# 0
# 0
# AlarmListTest_1638323676_251787 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.108001
# Commence processing of AlarmListTest_1638323685_251635
# 2022-04-07 11:13:48.231918
# 0
# 0
# AlarmListTest_1638323685_251635 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.143001
# Commence processing of AlarmListTest_1638323686_251955
# 2022-04-07 11:13:52.377918
# 0
# 0
# AlarmListTest_1638323686_251955 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.070000
# Commence processing of AlarmListTest_1638323690_252571
# 2022-04-07 11:13:52.451937
# 0
# 0
# AlarmListTest_1638323690_252571 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.139981
# Commence processing of AlarmListTest_1638323691_253790
# 2022-04-07 11:13:56.594918
# 0
# 0
# AlarmListTest_1638323691_253790 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.083001
# Commence processing of AlarmListTest_1638323715_252103
# 2022-04-07 11:13:56.680918
# 0
# 0
# AlarmListTest_1638323715_252103 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.067005
# Commence processing of AlarmListTest_1638323720_253952
# 2022-04-07 11:13:56.752921
# 0
# 0
# AlarmListTest_1638323720_253952 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.131997
# Commence processing of AlarmListTest_1638323721_253949
# 2022-04-07 11:13:56.888920
# 0
# 0
# AlarmListTest_1638323721_253949 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.092999
# Commence processing of AlarmListTest_1638323723_251968
# 2022-04-07 11:13:56.984918
# 0
# 0
# AlarmListTest_1638323723_251968 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.132871
# Commence processing of AlarmListTest_1638323728_251880
# 2022-04-07 11:14:01.121794
# 0
# 0
# AlarmListTest_1638323728_251880 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.117440
# Commence processing of AlarmListTest_1638323731_254179
# 2022-04-07 11:14:05.242232
# 0
# 0
# AlarmListTest_1638323731_254179 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.051001
# Commence processing of AlarmListTest_1638323733_252783
# 2022-04-07 11:14:05.295233
# 0
# 0
# AlarmListTest_1638323733_252783 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.082000
# Commence processing of AlarmListTest_1638323741_251637
# 2022-04-07 11:14:05.380233
# 0
# 0
# AlarmListTest_1638323741_251637 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069002
# Commence processing of AlarmListTest_1638323746_251631
# 2022-04-07 11:14:05.452234
# 0
# 0
# AlarmListTest_1638323746_251631 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.038999
# Commence processing of AlarmListTest_1638323753_252438
# 2022-04-07 11:14:05.493233
# 0
# 0
# AlarmListTest_1638323753_252438 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.161023
# Commence processing of AlarmListTest_1638323754_252423
# 2022-04-07 11:14:09.656255
# 0
# 0
# AlarmListTest_1638323754_252423 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.087002
# Commence processing of AlarmListTest_1638323779_252838
# 2022-04-07 11:14:09.746255
# 0
# 0
# AlarmListTest_1638323779_252838 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.142003
# Commence processing of AlarmListTest_1638323780_253673
# 2022-04-07 11:14:13.890255
# 0
# 0
# AlarmListTest_1638323780_253673 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.069999
# Commence processing of AlarmListTest_1638323800_252483
# 2022-04-07 11:14:13.962254
# 0
# 0
# AlarmListTest_1638323800_252483 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.078001
# Commence processing of AlarmListTest_1638323801_252468
# 2022-04-07 11:14:14.042254
# 0
# 0
# AlarmListTest_1638323801_252468 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.078001
# Commence processing of AlarmListTest_1638323802_251405
# 2022-04-07 11:14:14.122255
# 0
# 0
# AlarmListTest_1638323802_251405 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:04.156000
# Commence processing of AlarmListTest_1638323803_254570
# 2022-04-07 11:14:18.280255
# 0
# 0
# AlarmListTest_1638323803_254570 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.125000
# Commence processing of AlarmListTest_1638323812_254458
# 2022-04-07 11:14:18.407255
# 0
# 0
# AlarmListTest_1638323812_254458 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.088001
# Commence processing of AlarmListTest_1638323816_253466
# 2022-04-07 11:14:18.497255
# 0
# 0
# AlarmListTest_1638323816_253466 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.082000
# Commence processing of AlarmListTest_1638323817_252112
# 2022-04-07 11:14:18.581255
# 0
# 0
# AlarmListTest_1638323817_252112 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.085002
# Commence processing of AlarmListTest_1638323823_252165
# 2022-04-07 11:14:18.669257
# 0
# 0
# AlarmListTest_1638323823_252165 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.110001
# Commence processing of AlarmListTest_1638323824_252097
# 2022-04-07 11:14:18.782256
# 0
# 0
# AlarmListTest_1638323824_252097 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.090000
# Commence processing of AlarmListTest_1638323828_252005
# 2022-04-07 11:14:18.875255
# 0
# 0
# AlarmListTest_1638323828_252005 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.096000
# Commence processing of AlarmListTest_1638323831_253096
# 2022-04-07 11:14:18.974255
# 0
# 0
# AlarmListTest_1638323831_253096 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.094000
# Commence processing of AlarmListTest_1638323832_251861
# 2022-04-07 11:14:19.070255
# 0
# 0
# AlarmListTest_1638323832_251861 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.074001
# Commence processing of AlarmListTest_1638323833_251943
# 2022-04-07 11:14:19.146255
# 0
# 0
# AlarmListTest_1638323833_251943 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.055001
# Commence processing of AlarmListTest_1638323834_251820
# 2022-04-07 11:14:19.203255
# 0
# 0
# AlarmListTest_1638323834_251820 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.081000
# Commence processing of AlarmListTest_1638323835_251832
# 2022-04-07 11:14:19.286256
# 0
# 0
# AlarmListTest_1638323835_251832 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.082000
# Commence processing of AlarmListTest_1638323840_252718
# 2022-04-07 11:14:19.370256
# 0
# 0
# AlarmListTest_1638323840_252718 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.089999
# Commence processing of AlarmListTest_1638323846_251546
# 2022-04-07 11:14:19.462256
# 0
# 0
# AlarmListTest_1638323846_251546 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.058002
# Commence processing of AlarmListTest_1638323855_254416
# 2022-04-07 11:14:19.522257
# 0
# 0
# AlarmListTest_1638323855_254416 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.100998
# Commence processing of AlarmListTest_1638323857_252741
# 2022-04-07 11:14:19.625255
# 0
# 0
# AlarmListTest_1638323857_252741 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.084000
# Commence processing of AlarmListTest_1638323862_252320
# 2022-04-07 11:14:19.710256
# 0
# 0
# AlarmListTest_1638323862_252320 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.058000
# Commence processing of AlarmListTest_1638323875_252180
# 2022-04-07 11:14:19.770256
# 0
# 0
# AlarmListTest_1638323875_252180 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.083001
# Commence processing of AlarmListTest_1638323877_251955
# 2022-04-07 11:14:19.855255
# 0
# 0
# AlarmListTest_1638323877_251955 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.083000
# Commence processing of AlarmListTest_1638323879_253001
# 2022-04-07 11:14:19.940254
# 0
# 0
# AlarmListTest_1638323879_253001 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080002
# Commence processing of AlarmListTest_1638323897_251581
# 2022-04-07 11:14:20.022255
# 0
# 0
# AlarmListTest_1638323897_251581 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.080001
# Commence processing of AlarmListTest_1638323898_251588
# 2022-04-07 11:14:20.104255
# 0
# 0
# AlarmListTest_1638323898_251588 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.078000
# Commence processing of AlarmListTest_1638323907_254440
# 2022-04-07 11:14:20.184255
# 0
# 0
# AlarmListTest_1638323907_254440 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.089000
# Commence processing of AlarmListTest_1638323913_254252
# 2022-04-07 11:14:20.275255
# 0
# 0
# AlarmListTest_1638323913_254252 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.081004
# Commence processing of AlarmListTest_1638323922_251997
# 2022-04-07 11:14:20.357260
# 0
# 0
# AlarmListTest_1638323922_251997 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.084998
# Commence processing of AlarmListTest_1638323933_251971
# 2022-04-07 11:14:20.444259
# 0
# 0
# AlarmListTest_1638323933_251971 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.084999
# Commence processing of AlarmListTest_1638323934_251838
# 2022-04-07 11:14:20.530258
# 0
# 0
# AlarmListTest_1638323934_251838 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.089000
# Commence processing of AlarmListTest_1638323936_253704
# 2022-04-07 11:14:20.621255
# 0
# 0
# AlarmListTest_1638323936_253704 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.103002
# Commence processing of AlarmListTest_1638323937_251738
# 2022-04-07 11:14:20.725255
# 0
# 0
# AlarmListTest_1638323937_251738 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.092000
# Commence processing of AlarmListTest_1638323942_252603
# 2022-04-07 11:14:20.818255
# 0
# 0
# AlarmListTest_1638323942_252603 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.040000
# Commence processing of AlarmListTest_1638323946_252628
# 2022-04-07 11:14:20.859256
# 0
# 0
# AlarmListTest_1638323946_252628 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.051999
# Commence processing of AlarmListTest_1638323951_254811
# 2022-04-07 11:14:20.912254
# 0
# 0
# AlarmListTest_1638323951_254811 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.084003
# Commence processing of AlarmListTest_1638323952_251403
# 2022-04-07 11:14:20.997256
# 0
# 0
# AlarmListTest_1638323952_251403 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.089001
# Commence processing of AlarmListTest_1638323977_251935
# 2022-04-07 11:14:21.087256
# 0
# 0
# AlarmListTest_1638323977_251935 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.087001
# Commence processing of AlarmListTest_1638323989_252781
# 2022-04-07 11:14:21.175257
# 0
# 0
# AlarmListTest_1638323989_252781 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.087998
# Commence processing of AlarmListTest_1638323995_251545
# 2022-04-07 11:14:21.263255
# 0
# 0
# AlarmListTest_1638323995_251545 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.078000
# Commence processing of AlarmListTest_1638324002_251963
# 2022-04-07 11:14:21.341255
# 0
# 0
# AlarmListTest_1638324002_251963 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.096002
# Commence processing of AlarmListTest_1638324003_252573
# 2022-04-07 11:14:21.437257
# 0
# 0
# AlarmListTest_1638324003_252573 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079998
# Commence processing of AlarmListTest_1638324006_252484
# 2022-04-07 11:14:21.518255
# 0
# 0
# AlarmListTest_1638324006_252484 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.050002
# Commence processing of AlarmListTest_1638324017_254464
# 2022-04-07 11:14:21.569255
# 0
# 0
# AlarmListTest_1638324017_254464 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079000
# Commence processing of AlarmListTest_1638324018_254352
# 2022-04-07 11:14:21.648255
# 0
# 0
# AlarmListTest_1638324018_254352 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.108001
# Commence processing of AlarmListTest_1638324021_254118
# 2022-04-07 11:14:21.756256
# 0
# 0
# AlarmListTest_1638324021_254118 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.079999
# Commence processing of AlarmListTest_1638324022_254195
# 2022-04-07 11:14:21.836255
# 0
# 0
# AlarmListTest_1638324022_254195 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.074000
# Commence processing of AlarmListTest_1638324040_251705
# 2022-04-07 11:14:21.910255
# 0
# 0
# AlarmListTest_1638324040_251705 Transferred to destination folder ../AlarmLogs_archive/
# Run Tlapsed Time
# 0:00:00.074001
# Batch run completed
# 2022-04-07 11:14:21.984256
# Batch Elapsed Time
# 0:02:48.570879
# Script Terminated
# 2022-04-07 11:14:33.107274
# Operation Elapsed Time
# 0:02:59.696898

# %%
# Close Connection to Database
conn.close()
